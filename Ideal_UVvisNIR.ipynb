# %%
#### Arbitrary Sample 4 including Texture

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np


##   C:\Users\user\Desktop\Vac_Seal\UVvisNIR_Arbitrary_4

df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\UVvisNIR_Arbitrary_4.csv')
df
# Out:
#       Wave       Test_1      Test_2        Test_3        Test_4  \
# 0      2500  116.716049  116.892219  66977.773440  56229.972660
# 1      2499  116.235855    0.816569     -0.633477     13.470008
# 2      2498  115.626106    0.672934      0.036178     13.720892
# 3      2497  115.090050    0.872570     -0.225020     13.745602
# 4      2496  115.133965    0.428419      0.322374     14.251500
# ...     ...         ...         ...           ...           ...
# 2197    303   85.892174   24.825897   -145.280045    -33.058300
# 2198    302   84.695679    6.625518    -21.131878     -2.643667
# 2199    301   87.413879    1.850609      3.522386      2.743509
# 2200    300   85.574348   17.458652      3.062640    -17.607054
# 2201    299   82.337418         NaN           NaN           NaN
#
#       Test_5_Without  Test_6_Without  Test_7_Without
# 0       -2045.202271    35880.785160    58881.859380
# 1         101.688133       46.451290       10.181940
# ...

# %%
for i in range(1,8):
    plt.plot(df['Wave(nm)'], df.iloc[:, i])
    plt.legend(df.columns[1:])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Wave(nm)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt

headers = ['Wave','Test_1','Test_2','Test_3','Test_4','Test_5_Without','Test_6_Without','Test_7_Without']

# df = pd.read_csv(r':\Users\user\Desktop\Vac_Seal\UVvisNIR_Arbitrary_4.csv')

df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\UVvisNIR_Arbitrary_4.csv', names=headers, skiprows=[0])

plt.plot(df['Wave'], df['Test_1'], '-',color='red', label='No coating', lw=1)
plt.plot(df['wave'], df['Test_2'], '-', color='orange', label='10 cycles', lw=1)
plt.plot(df['wave'], df['Test_3'], '-', color='blue', label='25 Cycles', lw=1)
plt.plot(df['wave'], df['Test_4'], '-', color='green', label='50 Cycles', lw=1)
plt.plot(df['wave'], df['Test_5_Without'], '-', color='purple', label='100 Cycles', lw=1)
plt.plot(df['wave'], df['Test_6_Without'], '--', color='purple', label='100 Cycles', lw=1)
plt.plot(df['wave'], df['Test_7_Without'], '-.', color='purple', label='100 Cycles', lw=1)

plt.xlabel('Wavelength ($nm$)')
plt.ylabel('Transmittance (%)')
plt.xticks(np.arange(0, 2501, 500))
plt.xlim([250, 2500])
plt.ylim([50, 102])
plt.legend(loc='best', bbox_to_anchor=(0.03, 0.4))
plt.savefig('trans_ald_effect.jpeg', format='jpeg', dpi=1000)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'wave'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt

headers = ['Wave','Test_1','Test_2','Test_3','Test_4','Test_5_Without','Test_6_Without','Test_7_Without']

#df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\UVvisNIR_Arbitrary_4.csv')

df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\UVvisNIR_Arbitrary_4.csv', names=headers, skiprows=[0])
df
# Out:
#       Wave      Test_1      Test_2        Test_3        Test_4  \
# 0     2500  116.716049  116.892219  66977.773440  56229.972660
# 1     2499  116.235855    0.816569     -0.633477     13.470008
# 2     2498  115.626106    0.672934      0.036178     13.720892
# 3     2497  115.090050    0.872570     -0.225020     13.745602
# 4     2496  115.133965    0.428419      0.322374     14.251500
# ...    ...         ...         ...           ...           ...
# 2197   303   85.892174   24.825897   -145.280045    -33.058300
# 2198   302   84.695679    6.625518    -21.131878     -2.643667
# 2199   301   87.413879    1.850609      3.522386      2.743509
# 2200   300   85.574348   17.458652      3.062640    -17.607054
# 2201   299   82.337418         NaN           NaN           NaN
#
#       Test_5_Without  Test_6_Without  Test_7_Without
# 0       -2045.202271    35880.785160    58881.859380
# 1         101.688133       46.451290       10.181940
# ...

# %%
plt.plot(df['Wave'], df['Test_1'], '-',color='red', label='100%T', lw=1)
#plt.plot(df['Wave'], df['Test_2'], '-', color='orange', label='100%T', lw=1)
plt.plot(df['Wave'], df['Test_3'], '-', color='blue', label='0%T', lw=1)
plt.plot(df['Wave'], df['Test_4'], '--', color='green', label='A7_Without_1', lw=1)
#plt.plot(df['Wave'], df['Test_5_Without'], '-', color='purple', label='A7_With_2', lw=1)
plt.plot(df['Wave'], df['Test_6_Without'], '--', color='purple', label='A7_Without_2', lw=1)
plt.plot(df['Wave'], df['Test_7_Without'], '-', color='orange', label='A7_With', lw=1)

plt.title('Transmittance in UVvisNIR', fontdict={'fontsize': 16})
plt.xlabel('Wavelength ($nm$)', fontdict={'fontsize': 14} )
plt.ylabel('Transmittance (%)', fontdict={'fontsize': 14})
plt.xticks(np.arange(0, 2501, 500))
plt.xlim([300, 2500])
plt.ylim([0, 105])

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

#plt.legend(loc='best', bbox_to_anchor=(0.03, 0.4))
plt.savefig('trans_ald_effect.jpeg', format='jpeg', dpi=1000)
plt.show()

# %%
#plt.plot(df['Wave'], df['Test_1'], '-',color='red', label='100%T', lw=1)
#plt.plot(df['Wave'], df['Test_2'], '-', color='orange', label='100%T', lw=1)
#plt.plot(df['Wave'], df['Test_3'], '-', color='blue', label='0%T', lw=1)
plt.plot(df['Wave'], df['Test_4'], '--', color='green', label='A7_Without', lw=1)
#plt.plot(df['Wave'], df['Test_5_Without'], '-', color='purple', label='A7_With_2', lw=1)
#plt.plot(df['Wave'], df['Test_6_Without'], '--', color='purple', label='A7_Without_2', lw=1)
plt.plot(df['Wave'], df['Test_7_Without'], '-', color='orange', label='A7_With', lw=1)

plt.title('Transmittance in UVvisNIR', fontdict={'fontsize': 16})
plt.xlabel('Wavelength ($nm$)', fontdict={'fontsize': 14} )
plt.ylabel('Transmittance (%)', fontdict={'fontsize': 14})
plt.xticks(np.arange(0, 2501, 500))
plt.xlim([300, 2500])
plt.ylim([0, 105])

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

#plt.legend(loc='best', bbox_to_anchor=(0.03, 0.4))
plt.savefig('trans_ald_effect.jpeg', format='jpeg', dpi=1000)
plt.show()

# %%
#plt.plot(df['Wave'], df['Test_1'], '-',color='red', label='100%T', lw=1)
#plt.plot(df['Wave'], df['Test_2'], '-', color='orange', label='100%T', lw=1)
#plt.plot(df['Wave'], df['Test_3'], '-', color='blue', label='0%T', lw=1)
#plt.plot(df['Wave'], df['Test_4'], '--', color='green', label='A7_Without_1', lw=1)
#plt.plot(df['Wave'], df['Test_5_Without'], '-', color='purple', label='A7_With_2', lw=1)
plt.plot(df['Wave'], df['Test_6_Without'], '--', color='purple', label='A7_Without', lw=1)
plt.plot(df['Wave'], df['Test_7_Without'], '-', color='orange', label='A7_With', lw=1)

plt.title('Transmittance in UVvisNIR', fontdict={'fontsize': 16})
plt.xlabel('Wavelength ($nm$)', fontdict={'fontsize': 14} )
plt.ylabel('Transmittance (%)', fontdict={'fontsize': 14})
plt.xticks(np.arange(0, 2501, 100))
plt.xlim([340, 800])
plt.ylim([0, 105])

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

#plt.legend(loc='best', bbox_to_anchor=(0.03, 0.4))
plt.savefig('trans_ald_effect.jpeg', format='jpeg', dpi=1000)
plt.show()

# %%
### Sample with textutre

# %%
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
# Wavelength (nm)	0%T	100%	DF_WithoutTexture_1	DF_WithTexture	DF_Textured_Sample	Sample_WithoutSeal	DF_WithoutTexture_2	OnlyS_WithoutTexture	OnlyS_WithTexture

headers = ['Wavelength','0%T','100%T','DF_WithoutTexture_1','DF_WithTexture','DF_Textured_Sample','Sample_WithoutSeal','DF_WithoutTexture_2', 'OnlyS_WithoutTexture', 'OnlyS_WithTexture', 'Test_7_Without' ]

#df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\UVvisNIR_Arbitrary_4.csv')
#  C:\Users\user\Desktop\Vac_Seal\Film_Texture_Plain_Sample
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\Film_Texture_Plain_Sample.csv', names=headers, skiprows=[0])
df
# Out:
#       Wavelength         0%T     100%T  DF_WithoutTexture_1  DF_WithTexture  \
# 0           2500  111.161682 -1.423649            60.074638       60.720467
# 1           2499  111.335991  1.294643            58.902569       56.221664
# 2           2498  112.504730  0.464388            60.216152       59.991859
# 3           2497  112.769875  2.564907            58.971111       55.604362
# 4           2496  113.522270 -0.655275            59.197296       58.083389
# ...          ...         ...       ...                  ...             ...
# 2197         303   78.204002 -1.379182            41.945866       85.817703
# 2198         302   77.977722  1.045089            37.891724       78.265671
# 2199         301   78.536560 -0.007938            50.522495       79.370583
# 2200         300   78.629860 -4.080522            43.815269       64.604973
# 2201         299   78.628761       NaN                  NaN             NaN
#
# ...

# %%
#plt.plot(df['Wavelength'], df['0%T'], '-',color='red', label='100%T', lw=1)
#plt.plot(df['Wavelength'], df['100%T'], '-', color='orange', label='100%T', lw=1)
#plt.plot(df['Wavelength'], df['DF_WithoutTexture_1'], '-', color='blue', label='0%T', lw=1)
#plt.plot(df['Wavelength'], df['DF_WithTexture'], '--', color='green', label='A7_Without_1', lw=1)
plt.plot(df['Wavelength'], df['DF_Textured_Sample'], '-', color='purple', label='A7_WithSeal', lw=1)
plt.plot(df['Wavelength'], df['Sample_WithoutSeal'], '--', color='purple', label='A7_Without', lw=1)
#plt.plot(df['Wavelength'], df['DF_WithoutTexture_2'], '-', color='orange', label='A7_With', lw=1)
#plt.plot(df['Wavelength'], df['OnlyS_WithoutTexture'], '-', color='orange', label='A7_With', lw=1)
#plt.plot(df['Wavelength'], df['OnlyS_WithTexture'], '-', color='orange', label='A7_With', lw=1)
#plt.plot(df['Wavelength'], df['Test_7_Without'], '-', color='green', label='A7_With', lw=1)

plt.title('Transmittance in UVvisNIR', fontdict={'fontsize': 16})
plt.xlabel('Wavelength ($nm$)', fontdict={'fontsize': 14} )
plt.ylabel('Transmittance (%)', fontdict={'fontsize': 14})
plt.xticks(np.arange(0, 2501, 500))
plt.xlim([300, 2500])
plt.ylim([0, 105])

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

#plt.legend(loc='best', bbox_to_anchor=(0.03, 0.4))
plt.savefig('trans_ald_effect.jpeg', format='jpeg', dpi=1000)
plt.show()

# %%
plt.plot(df['Wavelength'], df['0%T'], '--',color='red', label='100%T', lw=1)
plt.plot(df['Wavelength'], df['100%T'], '-', color='red', label='0%T', lw=1)
plt.plot(df['Wavelength'], df['DF_WithoutTexture_1'], '-', color='orange', label='DF_WithoutTexture', lw=1)
plt.plot(df['Wavelength'], df['DF_WithTexture'], '--', color='green', label='DF_WithTexture', lw=1)
plt.plot(df['Wavelength'], df['DF_Textured_Sample'], '--', color='purple', label='A7_DF_Texture', lw=1)
plt.plot(df['Wavelength'], df['Sample_WithoutSeal'], '--', color='yellow', label='A7_WithoutSeal', lw=1)
#plt.plot(df['Wavelength'], df['DF_WithoutTexture_2'], '-', color='orange', label='DFilm_2', lw=1)
#plt.plot(df['Wavelength'], df['OnlyS_WithoutTexture'], '-', color='orange', label='SFilm', lw=1)
#plt.plot(df['Wavelength'], df['OnlyS_WithTexture'], '-', color='orange', label='A7_With', lw=1)


plt.title('Transmittance in UVvisNIR', fontdict={'fontsize': 16})
plt.xlabel('Wavelength ($nm$)', fontdict={'fontsize': 14} )
plt.ylabel('Transmittance (%)', fontdict={'fontsize': 14})
plt.xticks(np.arange(0, 2501, 500))
plt.xlim([300, 2500])
plt.ylim([0, 105])

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

#plt.legend(loc='best', bbox_to_anchor=(0.03, 0.4))
plt.savefig('trans_ald_effect.jpeg', format='jpeg', dpi=1000)
plt.show()

# %%
#plt.plot(df['Wavelength'], df['0%T'], '-',color='red', label='100%T', lw=1)
#plt.plot(df['Wavelength'], df['100%T'], '-', color='orange', label='100%T', lw=1)
#plt.plot(df['Wavelength'], df['DF_WithoutTexture_1'], '-', color='blue', label='0%T', lw=1)
#plt.plot(df['Wavelength'], df['DF_WithTexture'], '--', color='green', label='A7_Without_1', lw=1)
plt.plot(df['Wavelength'], df['DF_Textured_Sample'], '-', color='purple', label='A7_DF_Plain', lw=1)
plt.plot(df['Wavelength'], df['Sample_WithoutSeal'], '--', color='orange', label='A7_WithoutSeal', lw=1)
#plt.plot(df['Wavelength'], df['DF_WithoutTexture_2'], '-', color='orange', label='A7_With', lw=1)
#plt.plot(df['Wavelength'], df['OnlyS_WithoutTexture'], '-', color='orange', label='A7_With', lw=1)
#plt.plot(df['Wavelength'], df['OnlyS_WithTexture'], '-', color='orange', label='A7_With', lw=1)
plt.plot(df['Wavelength'], df['Test_7_Without'], '-', color='green', label='A7_DF_Texture', lw=1)

plt.title('Transmittance in UVvisNIR', fontdict={'fontsize': 16})
plt.xlabel('Wavelength ($nm$)', fontdict={'fontsize': 14} )
plt.ylabel('Transmittance (%)', fontdict={'fontsize': 14})
plt.xticks(np.arange(0, 2501, 500))
plt.xlim([300, 2500])
plt.ylim([0, 105])

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

#plt.legend(loc='best', bbox_to_anchor=(0.03, 0.4))
plt.savefig('trans_ald_effect.jpeg', format='jpeg', dpi=1000)
plt.show()

# %%
#plt.plot(df['Wavelength'], df['0%T'], '-',color='red', label='100%T', lw=1)
#plt.plot(df['Wavelength'], df['100%T'], '-', color='orange', label='100%T', lw=1)
#plt.plot(df['Wavelength'], df['DF_WithoutTexture_1'], '-', color='blue', label='0%T', lw=1)
#plt.plot(df['Wavelength'], df['DF_WithTexture'], '--', color='green', label='A7_Without_1', lw=1)
#plt.plot(df['Wavelength'], df['DF_Textured_Sample'], '-', color='purple', label='A7_DF_Plain', lw=1)
#plt.plot(df['Wavelength'], df['Sample_WithoutSeal'], '--', color='orange', label='A7_WithoutSeal', lw=1)
plt.plot(df['Wavelength'], df['DF_WithoutTexture_2'], '-', color='orange', label='DF_Plain', lw=1)
#plt.plot(df['Wavelength'], df['OnlyS_WithoutTexture'], '-', color='green', label='SF_Texture', lw=1)
plt.plot(df['Wavelength'], df['OnlyS_WithTexture'], '-', color='purple', label='DF_Texture', lw=1)
#plt.plot(df['Wavelength'], df['Test_7_Without'], '-', color='green', label='A7_DF_Texture', lw=1)

plt.title('Transmittance in UVvisNIR', fontdict={'fontsize': 16})
plt.xlabel('Wavelength ($nm$)', fontdict={'fontsize': 14} )
plt.ylabel('Transmittance (%)', fontdict={'fontsize': 14})
plt.xticks(np.arange(0, 2501, 500))
plt.xlim([300, 2500])
plt.ylim([60, 105])

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

#plt.legend(loc='best', bbox_to_anchor=(0.03, 0.4))
plt.savefig('trans_ald_effect.jpeg', format='jpeg', dpi=1000)
plt.show()

# %%
### Ideal Sample

# %%
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt

# Wave	100%T	0%T	A3_WithoutS	A7_WithoutS	A7_WithoutS	A21_WithoutS	A39_WithoutS						

headers = ['Wavelength','100%T','0%T','A3_WithoutS','A7_WithoutS','A14_WithoutS','A21_WithoutS','A39_WithoutS']

#df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\UVvisNIR_Arbitrary_4.csv')
#  C:\Users\user\Desktop\Vac_Seal\Film_Texture_Plain_Sample
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\IdealSample_1.csv', names=headers, skiprows=[0])
df
# Out:
#       Wavelength       100%T         0%T  A3_WithoutS  A7_WithoutS  \
# 0           2500  100.803391    0.405397    64.808395    54.088818
# 1           2499  101.866852    0.789137    62.822353    52.501553
# 2           2498  101.369186    0.385904    63.405842    54.734974
# 3           2497  100.858032   -0.168589    65.072235    54.190426
# 4           2496  101.131393   -0.294967    64.610786    54.138279
# ...          ...         ...         ...          ...          ...
# 2197         303   78.335564  322.943726    85.109749    90.447495
# 2198         302   63.246094  439.696655    94.658890    92.726700
# 2199         301   73.764717  473.901520    90.714226    87.487343
# 2200         300   66.286644  231.254150    94.218086    76.984833
# 2201         299   85.600632         NaN          NaN          NaN
#
#       A14_WithoutS  A21_WithoutS  A39_WithoutS
# 0        53.679775     46.154694     58.420666
# 1        52.517857     46.044933     58.704876
# ...

# %%
#plt.plot(df['Wavelength'], df['100%T'], '-',color='red', label='100%T', lw=1)
#plt.plot(df['Wavelength'], df['0%T'], '-', color='blue', label='0%T', lw=1)
#plt.plot(df['Wavelength'], df['DF_WithoutTexture_1'], '-', color='blue', label='0%T', lw=1)
plt.plot(df['Wavelength'], df['A3_WithoutS'], '--', color='green', label='A3_WithoutS', lw=1)
plt.plot(df['Wavelength'], df['A7_WithoutS'], '--', color='purple', label='A7_WithoutS', lw=1)
plt.plot(df['Wavelength'], df['A14_WithoutS'], '--', color='yellow', label='A14_WithoutS', lw=1)
plt.plot(df['Wavelength'], df['A21_WithoutS'], '--', color='orange', label='A21_WithoutS', lw=1)
plt.plot(df['Wavelength'], df['A39_WithoutS'], '--', color='black', label='A39_WithoutS', lw=1)

plt.title('Transmittance in UVvisNIR', fontdict={'fontsize': 16})
plt.xlabel('Wavelength ($nm$)', fontdict={'fontsize': 14} )
plt.ylabel('Transmittance (%)', fontdict={'fontsize': 14})
plt.xticks(np.arange(0, 2501, 500))
plt.xlim([300, 2500])
plt.ylim([0, 105])

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

#plt.legend(loc='best', bbox_to_anchor=(0.03, 0.4))
plt.savefig('trans_ald_effect.jpeg', format='jpeg', dpi=1000)
plt.show()

# %%
#plt.plot(df['Wavelength'], df['100%T'], '-',color='red', label='100%T', lw=1)
#plt.plot(df['Wavelength'], df['0%T'], '-', color='blue', label='0%T', lw=1)
#plt.plot(df['Wavelength'], df['DF_WithoutTexture_1'], '-', color='blue', label='0%T', lw=1)
plt.plot(df['Wavelength'], df['A3_WithoutS'], '--', color='green', label='A3_WithoutS', lw=1)
plt.plot(df['Wavelength'], df['A7_WithoutS'], '--', color='purple', label='A7_WithoutS', lw=1)
plt.plot(df['Wavelength'], df['A14_WithoutS'], '--', color='yellow', label='A14_WithoutS', lw=1)
plt.plot(df['Wavelength'], df['A21_WithoutS'], '--', color='orange', label='A21_WithoutS', lw=1)
plt.plot(df['Wavelength'], df['A39_WithoutS'], '--', color='black', label='A39_WithoutS', lw=1)

plt.title('Transmittance in UVvisNIR', fontdict={'fontsize': 16})
plt.xlabel('Wavelength ($nm$)', fontdict={'fontsize': 14} )
plt.ylabel('Transmittance (%)', fontdict={'fontsize': 14})
plt.xticks(np.arange(0, 2501, 500))
plt.xlim([300, 2500])
plt.ylim([0, 105])

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

#plt.legend(loc='best', bbox_to_anchor=(0.03, 0.4))
plt.savefig('trans_ald_effect.jpeg', format='jpeg', dpi=1000)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'A3_WithoutS'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
## Ideal sdample with Seal

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Wavelength	100%T	0%T	A1_Sealed	A3_Sealed	A7_Sealed	A14_Sealed	A21_Sealed	A39_Sealed							


headers = ['Wavelength','100%T','0%T','A1_Sealed','A3_Sealed','A7_Sealed','A14_Sealed','A21_Sealed', 'A39_Sealed',]

# C:\Users\user\Desktop\Vac_Seal\IdealSample

# df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\Film_Texture_Plain_Sample.csv', names=headers, skiprows=[0])


df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\IdealSample\IdealSample_WithS_UVvisNIR.csv', names=headers, skiprows=[0])
df
# Out:
#       Wavelength       100%T        0%T  A1_Sealed  A3_Sealed  A7_Sealed  \
# 0           2500  107.411346  -0.283990  17.327208  25.633451  21.470121
# 1           2499  106.886078   0.106196  15.934266  24.185738  20.192995
# 2           2498  104.848877   1.577957  16.266203  25.093477  19.512848
# 3           2497  106.879822   0.627859  16.955311  23.423298  19.893372
# 4           2496  106.565262  -0.557661  17.308966  24.378576  21.849976
# ...          ...         ...        ...        ...        ...        ...
# 2197         303   86.519844 -47.755207 -27.633434  42.445988  42.662914
# 2198         302   76.004135 -30.907640 -74.527290  36.954124  36.595352
# 2199         301   71.607567 -37.486496 -13.722050  41.151951  39.515938
# 2200         300   70.327667 -68.661636  -5.816210  53.526020  53.376919
# 2201         299   82.826431        NaN        NaN        NaN        NaN
#
#       A14_Sealed  A21_Sealed  A39_Sealed
# 0      24.592442   18.891172   25.807358
# ...

# %%
#plt.plot(df['Wavelength'], df['100%T'], '-',color='red', label='100%T', lw=1)
#plt.plot(df['Wavelength'], df['0%T'], '-', color='blue', label='0%T', lw=1)
plt.plot(df['Wavelength'], df['A1_Sealed'], '-', color='blue', label='A1_Sealed', lw=1)
plt.plot(df['Wavelength'], df['A3_Sealed'], '-', color='green', label='A3_Sealed', lw=1)
plt.plot(df['Wavelength'], df['A7_Sealed'], '-', color='purple', label='A7_Sealed', lw=1)
plt.plot(df['Wavelength'], df['A14_Sealed'], '-', color='yellow', label='A14_Sealed', lw=1)
plt.plot(df['Wavelength'], df['A21_Sealed'], '-', color='orange', label='A21_Sealed', lw=1)
plt.plot(df['Wavelength'], df['A39_Sealed'], '-', color='black', label='A39_Sealed', lw=1)

plt.title('Transmittance in UVvisNIR', fontdict={'fontsize': 16})
plt.xlabel('Wavelength ($nm$)', fontdict={'fontsize': 14} )
plt.ylabel('Transmittance (%)', fontdict={'fontsize': 14})
plt.xticks(np.arange(0, 2501, 500))
plt.xlim([300, 2500])
plt.ylim([0, 105])

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

#plt.legend(loc='best', bbox_to_anchor=(0.03, 0.4))
plt.savefig('trans_ald_effect.jpeg', format='jpeg', dpi=1000)
plt.show()
