# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_2\\Specimen_RawData_5 - Copy.csv',names = headers, skiprows=skip)

from scipy.interpolate import interp1d

time1 = np.arange(0,314)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/(4/np.pi))*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100

# plt.plot(strain_per, stress, '-', color = 'blue', label='7 days', lw=1) 

plt.plot(strain_per, stress, '-', color = 'g',label='7D_1_Sealed')
plt.legend(loc='best')
plt.xlim(0,.015)
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_2\\Specimen_RawData_6.csv',names = headers, skiprows=skip)

from scipy.interpolate import interp1d

time1 = np.arange(0,66)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(10),mode = 'same')/10

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100

# plt.plot(strain_per, stress, '-', color = 'blue', label='7 days', lw=1) 

plt.plot(strain_per, stress, '-', color = 'g',label='7D_1_unsealed')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,5)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_2\\Specimen_RawData_7.csv',names = headers, skiprows=skip)

from scipy.interpolate import interp1d

time1 = np.arange(0,86)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(5),mode = 'same')/5

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100

# plt.plot(strain_per, stress, '-', color = 'blue', label='7 days', lw=1) 

plt.plot(strain_per, stress, '-', color = 'g',label='7D_2_Sealed')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_2\\Specimen_RawData_8.csv',names = headers, skiprows=skip)

from scipy.interpolate import interp1d

time1 = np.arange(0,120)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(20),mode = 'same')/20

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100

# plt.plot(strain_per, stress, '-', color = 'blue', label='7 days', lw=1) 

plt.plot(strain_per, stress, '-', color = 'g',label='7D_2_unsealed')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_2\\Specimen_RawData_5 - Copy.csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

time1 = np.arange(0,314)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='-', color = 'blue',label='7 D_1_with')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
## plt.show()



import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_2\\Specimen_RawData_6.csv',names = headers, skiprows=skip)

from scipy.interpolate import interp1d

time1 = np.arange(0,66)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(10),mode = 'same')/10

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100

# plt.plot(strain_per, stress, '-', color = 'blue', label='7 D_2_without', lw=1) 
plt.plot(strain_per, stress, '-', linestyle='dashed', color = 'blue',label='7 D_1_without')
#plt.plot(strain_per, stress, '-', color = 'b',label='7 D_2')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
#  plt.show()


import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,5)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_2\\Specimen_RawData_7.csv',names = headers, skiprows=skip)

from scipy.interpolate import interp1d

time1 = np.arange(0,86)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(5),mode = 'same')/5

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100

# plt.plot(strain_per, stress, '-', color = 'blue', label='7 days', lw=1) 
plt.plot(strain_per, stress, '-', linestyle='-', color = 'orange',label='7 D_2_with')
#plt.plot(strain_per, stress, '-', color = 'r',label='7D_2_Sealed')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
##  plt.show()

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_2\\Specimen_RawData_8.csv',names = headers, skiprows=skip)

from scipy.interpolate import interp1d

time1 = np.arange(0,120)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(20),mode = 'same')/20

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100

# plt.plot(strain_per, stress, '-', color = 'blue', label='7 days', lw=1) 
#plt.plot(strain_per, stress, '-', linestyle='dashed', color = 'orange',label='7 D_2_without'
plt.plot(strain_per, stress, '-', linestyle='dashed', color = 'orange',label='7 D_2_without')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.xlim(0,.1)
plt.show()
# Out:
# C:\Users\t470\AppData\Local\Temp/ipykernel_4656/3285187458.py:35: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='-', color = 'blue',label='7 D_1_with')
# C:\Users\t470\AppData\Local\Temp/ipykernel_4656/3285187458.py:78: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='dashed', color = 'blue',label='7 D_1_without')
# C:\Users\t470\AppData\Local\Temp/ipykernel_4656/3285187458.py:121: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='-', color = 'orange',label='7 D_2_with')
# C:\Users\t470\AppData\Local\Temp/ipykernel_4656/3285187458.py:164: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='dashed', color = 'orange',label='7 D_2_without')

# %%
#### Load vs extension

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_2\\Specimen_RawData_2.csv')
df
# Out:
#          (s)  Extension  16 D_without seal  16 D_with seal  21 D_without seal  \
# 0      0.000   -0.70340           -0.14049        -0.11666           -0.13767
# 1      0.028   -0.70340           -0.05240        -0.06744           -0.04738
# 2      0.054   -0.70340           -0.08312        -0.06807            0.00403
# 3      0.080   -0.70340           -0.11165        -0.04801           -0.02826
# 4      0.106   -0.70329           -0.06588        -0.05773           -0.12450
# ...      ...        ...                ...             ...                ...
# 3012  78.314   -0.05077            0.81347             NaN                NaN
# 3013  78.340   -0.05055            0.86175             NaN                NaN
# 3014  78.366   -0.05032            0.83510             NaN                NaN
# 3015  78.392   -0.05009            0.86332             NaN                NaN
# 3016  78.398   -0.05009            0.87523             NaN                NaN
#
#       21 D_with seal
# 0           -0.09691
# 1           -0.11447
# 2            0.04824
# 3            0.05827
# 4           -0.04393
# ...              ...
# 3012             NaN
# 3013             NaN
# 3014             NaN
# 3015             NaN
# 3016             NaN
#
# [3017 rows x 6 columns]

# %%
from scipy.signal import lfilter

plt.rcParams["figure.figsize"] = (16,10)

# plt.plot(df.Extension, df['16 D_without seal'])
n = 100  # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
yy = lfilter(b,a, df['16 D_without seal'])
#plt.plot(df.Extension, yy, linewidth=2, linestyle="-", color="blue")
plt.plot(df.Extension, yy, linewidth=2, linestyle='dashed', color="blue", label='16 D_without seal')



# plt.plot(df.Extension, df['16 D_with seal'])
n = 100  # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
yy = lfilter(b,a, df['16 D_with seal'])
#plt.plot(df.Extension, yy, linewidth=2, linestyle="-", color="red")
plt.plot(df.Extension, yy, linewidth=2, linestyle="-", color="blue", label='16 D_with seal' )


# plt.plot(df.Extension, df['21 D_without seal'])
n = 100  # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
yy = lfilter(b,a, df['21 D_without seal'])
plt.plot(df.Extension, yy, linewidth=2, linestyle='dashed', color="orange",label='21 D_without seal' )





# plt.plot(df.Extension, df['21 D_with seal'])
n = 100  # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
yy = lfilter(b,a, df['21 D_with seal'])
plt.plot(df.Extension, yy, linewidth=2, linestyle="-", color="orange", label='21 D_with seal' )
plt.legend(loc='best',fontsize=14)
plt.title('Load vs Extension', fontdict={'fontsize': 16})
plt.xlabel('Extension (mm)',fontdict={'fontsize': 14})
plt.ylabel('Load(MPa)',fontdict={'fontsize': 14})

# plt.legend()

# plt.plot(strain_per, stress, '-', color = 'g',linestyle='dashed', label='21 Days_without sealing')
# plt.legend(loc='best',fontsize=14)
# plt.title('Aging Strengths', fontdict={'fontsize': 16})
# plt.xlabel('% Strain',fontdict={'fontsize': 14})
# plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 14})

plt.show()

# %%
from scipy.signal import lfilter

n = 300  # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
yy = lfilter(b,a, df.load)
plt.plot(df.Extension, yy, linewidth=2, linestyle="-", c="b")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4656/2622956264.py in <module>
#       4 b = [1.0 / n] * n
#       5 a = 1
# ----> 6 yy = lfilter(b,a, df.load)
#       7 plt.plot(df.Extension, yy, linewidth=2, linestyle="-", c="b")
#       8
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'load'

# %%
df['Specimen_RawData_5']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Specimen_RawData_5'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4656/2240364001.py in <module>
# ----> 1 df['Specimen_RawData_5']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Specimen_RawData_5'
