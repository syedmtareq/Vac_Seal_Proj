# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

df = pd.read_excel(r'C:\Users\user\Desktop\Vac_Seal\aerogel_uvvis\Without_Comb.xlsx')
df
# Out:
#       Wave(nm)  A1(%T)  A3(%T)  A7(%T)  A16(%T)  A1(%T).1  A3(%T).1  A7(%T).1  \
# 0        340.0    9.92   19.74   49.66    63.56      2.93     14.59      8.17
# 1        340.5    9.99   19.93   49.80    63.57      2.97     14.65      8.30
# 2        341.0   10.08   20.12   49.91    63.58      2.92     14.69      8.35
# 3        341.5   10.17   20.35   50.11    63.72      2.97     14.84      8.51
# 4        342.0   10.27   20.44   50.26    63.80      2.98     14.91      8.51
# ...        ...     ...     ...     ...      ...       ...       ...       ...
# 1316     998.0   63.96   83.41   97.21    73.83     24.15     57.12     62.51
# 1317     998.5   63.83   83.57   97.26    73.75     24.14     57.16     62.48
# 1318     999.0   63.84   83.69   97.41    73.76     24.09     57.26     62.37
# 1319     999.5   63.77   83.86   97.57    73.87     24.18     57.47     62.46
# 1320    1000.0   63.83   83.88   97.72    74.02     24.26     57.56     62.44
#
#       A16(%T).1
# ...

# %%
# plt.plot(df['Wave(nm)'], df['A1(%T)'])
# plt.plot(df['Wave(nm)'], df.iloc[:, 1])
for i in range(1,9):
    plt.plot(df['Wave(nm)'], df.iloc[:, i])
    plt.legend(df.columns[1:])
plt.show()

# %%
plt.plot(df['Wave(nm)'], df.iloc[:, 1])
plt.plot(df['Wave(nm)'], df.iloc[:, 2])
plt.plot(df['Wave(nm)'], df.iloc[:, 3])
plt.plot(df['Wave(nm)'], df.iloc[:, 4])

# %%
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="orange",label='7 D_2_with' )

plt.plot(df['Wave(nm)'], df.iloc[:, 1], linestyle='--', color="blue", label='A1_Without')
plt.plot(df['Wave(nm)'], df.iloc[:, 2], linestyle='--', color="orange", label='A3_Without')
plt.plot(df['Wave(nm)'], df.iloc[:, 3], linestyle='--', color="green", label='A7_Without')
plt.plot(df['Wave(nm)'], df.iloc[:, 4], linestyle='--', color="red", label='A16_Without')
plt.plot(df['Wave(nm)'], df.iloc[:, 5], linestyle='-', color="blue", label='A1_With')
plt.plot(df['Wave(nm)'], df.iloc[:, 6], linestyle='-', color="orange", label='A3_With')
plt.plot(df['Wave(nm)'], df.iloc[:, 7], linestyle='-', color="green", label='A7_With')
plt.plot(df['Wave(nm)'], df.iloc[:, 8], linestyle='-', color="red", label='A16_With')


#plt.legend(loc='lower right',fontsize=12)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.title('Transmittence vs age and seal', fontdict={'fontsize': 16})
plt.xlabel('Wave (nm)',fontdict={'fontsize': 14})
plt.ylabel('Transmittance(%T)',fontdict={'fontsize': 14})
# Out:
# Text(0, 0.5, 'Transmittance(%T)')

# %%
## Mirror placement

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

headers = ['Wave','ML_Without_F1','ML_Without_B2','ML_With_F3','ML_With_B4','M_Without_F5','M_Without_6','M_With_F7','M_With_B8']

#C:\Users\user\Desktop\Vac_Seal\Mirror
#df = pd.read_excel(r'C:\Users\user\Desktop\Vac_Seal\Mirror.xlsx')
#df


df = pd.read_excel(r'C:\Users\user\Desktop\Vac_Seal\Mirror\Mirror.xlsx')
df
# Out:
#         Wave  ML_Without_F1  ML_Without_B2  ML_With_F3  ML_With_B4  \
# 0      340.0          57.55          29.68       12.29       11.85
# 1      340.5          57.51          29.63       12.35       11.88
# 2      341.0          57.54          29.61       12.39       11.96
# 3      341.5          57.63          29.64       12.50       12.04
# 4      342.0          57.67          29.66       12.61       12.12
# ...      ...            ...            ...         ...         ...
# 1316   998.0          61.23          31.92       56.47       55.38
# 1317   998.5          61.10          31.85       56.42       55.25
# 1318   999.0          61.05          31.96       56.37       55.26
# 1319   999.5          61.01          31.95       56.39       55.18
# 1320  1000.0          60.97          32.08       56.53       55.19
#
#       M_Without_F5  M_Without_B6  M_With_F7  M_With_B8
# 0             1.85          1.71      11.23      10.03
# ...

# %%
#plt.plot(df['Wave'], df.iloc[:, 1], linestyle='--', color="blue", label='WithM_WithoutS_F1')
#plt.plot(df['Wave'], df.iloc[:, 2], linestyle='--', color="orange", label='WithoutM_WithoutS_B2')
plt.plot(df['Wave'], df.iloc[:, 3], linestyle='--', color="green", label='WithM_WithoutS_1')
#plt.plot(df['Wave'], df.iloc[:, 4], linestyle='-', color="orange", label='WithoutM_WithoutS_B4')
plt.plot(df['Wave'], df.iloc[:, 5], linestyle='-', color="green", label='WithoutM_WithoutS_1')
#plt.plot(df['Wave'], df.iloc[:, 6], linestyle='-', color="green", label='WithoutM_WithoutS_B6')
plt.plot(df['Wave'], df.iloc[:, 7], linestyle='--', color="blue", label='WithM_WithS_2')
plt.plot(df['Wave'], df.iloc[:, 8], linestyle='-', color="blue", label='WithoutM_WithS_2')


#plt.legend(loc='lower right',fontsize=12)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.title('Transmittence in UVvis', fontdict={'fontsize': 16})

plt.xlim([340, 800])
plt.ylim([0, 105])


plt.xlabel('Wavelength (nm)',fontdict={'fontsize': 14})
plt.ylabel('Transmittance(%T)',fontdict={'fontsize': 14})
# Out:
# Text(0, 0.5, 'Transmittance(%T)')

# %%
#plt.plot(df['Wave'], df.iloc[:, 1], linestyle='--', color="blue", label='WithM_WithoutS_F1')
#plt.plot(df['Wave'], df.iloc[:, 2], linestyle='--', color="orange", label='WithoutM_WithoutS_B2')
plt.plot(df['Wave'], df.iloc[:, 3], linestyle='--', color="green", label='WithM_WithoutS_F3')
plt.plot(df['Wave'], df.iloc[:, 4], linestyle='--', color="orange", label='WithoutM_WithoutS_B4')
plt.plot(df['Wave'], df.iloc[:, 5], linestyle='--', color="red", label='WithM_WithS_F5')
plt.plot(df['Wave'], df.iloc[:, 6], linestyle='-', color="green", label='WithoutM_WithS_B6')
plt.plot(df['Wave'], df.iloc[:, 7], linestyle='-', color="blue", label='WithM_WithS_F7')
plt.plot(df['Wave'], df.iloc[:, 8], linestyle='-', color="red", label='WithM_WithS_B8')


#plt.legend(loc='lower right',fontsize=12)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.title('Transmittence in UVvis', fontdict={'fontsize': 16})
plt.xlabel('Wave (nm)',fontdict={'fontsize': 14})
plt.ylabel('Transmittance(%T)',fontdict={'fontsize': 14})
# Out:
# Text(0, 0.5, 'Transmittance(%T)')
