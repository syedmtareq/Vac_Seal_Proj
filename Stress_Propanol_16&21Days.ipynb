# %%
# Propalin as SE and 16 days aging

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_2\\Specimen_RawData_1.csv',names = headers, skiprows=skip)

from scipy.interpolate import interp1d

time1 = np.arange(0,36)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

stress = 6*M/(t**2)
dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100

# plt.plot(strain_per, stress, '-', color = 'blue', label='7 days', lw=1) 

plt.plot(strain_per, stress, '-', color = 'g',label='16 Days')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_2\\Specimen_RawData_2.csv',names = headers, skiprows=skip)

from scipy.interpolate import interp1d

time1 = np.arange(0,36)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

stress = 6*M/(t**2)
dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
mini = np.abs(strain_per.min())
# plt.plot(strain_per, stress, '-', color = 'blue', label='7 days', lw=1) 

plt.plot(strain_per + mini, stress, '-', color = 'g',label='16 days_without sealing')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_2\\Specimen_RawData_1.csv',names = headers, skiprows=skip)

from scipy.interpolate import interp1d

time1 = np.arange(0,36)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

stress = 6*M/(t**2)
dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100

# plt.plot(strain_per, stress, '-', color = 'blue', label='7 days', lw=1) 
plt.figure(figsize=(12,6))
plt.plot(strain_per, stress, '-',color = 'b',label='16 Days')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})


import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_2\\Specimen_RawData_2.csv',names = headers, skiprows=skip)

from scipy.interpolate import interp1d

time1 = np.arange(0,76)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

stress = 6*M/(t**2)
dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
mini = np.abs(strain_per.min())
# plt.plot(strain_per, stress, '-', color = 'blue', label='7 days', lw=1) 

plt.plot(strain_per + mini, stress, '-', color = 'b',linestyle='dashed',label='16 days_without sealing')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.show()
# Out:
# C:\Users\t470\AppData\Local\Temp/ipykernel_14676/467135305.py:74: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per + mini, stress, '-', color = 'b',linestyle='dashed',label='16 days_without sealing')

# %%
# Propelin as SE and 21 days aging

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_2\\Specimen_RawData_3.csv',names = headers, skiprows=skip)

from scipy.interpolate import interp1d

time1 = np.arange(0,56)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

#stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(5),mode = 'same')/5
dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100

# plt.plot(strain_per, stress, '-', color = 'blue', label='7 days', lw=1) 

plt.plot(strain_per, stress, '-', color = 'g',label='7 Days')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.interpolate import interp1d

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_2\\Specimen_RawData_4.csv',names = headers, skiprows=skip)

from scipy.interpolate import interp1d

time1 = np.arange(0,76)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))


#stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(10),mode = 'same')/10

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100


# plt.plot(strain_per, stress, '-', color = 'blue', label='7 days', lw=1) 

plt.plot(strain_per, stress, '-', color = 'g',label='7 Days')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
plt.rcParams["figure.figsize"] = (16,10)

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_2\\Specimen_RawData_1.csv',names = headers, skiprows=skip)

from scipy.interpolate import interp1d

time1 = np.arange(0,36)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

stress = 6*M/(t**2)
dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100

# plt.plot(strain_per, stress, '-', color = 'blue', label='16 D_without seal', lw=1) 
#plt.figure(figsize=(12,6))

# n = 100  # the larger n is, the smoother curve will be
# b = [1.0 / n] * n
# a = 1
# yy = lfilter(b,a, df['16 D_without seal'])

plt.plot(strain_per, stress, '-',color = 'b',label='16 D_without seal')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})


import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_2\\Specimen_RawData_2 - Copy.csv',names = headers, skiprows=skip)

from scipy.interpolate import interp1d

time1 = np.arange(0,76)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

stress = 6*M/(t**2)
dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
mini = np.abs(strain_per.min())
# plt.plot(strain_per, stress, '-', color = 'blue', label='7 days', lw=1) 

plt.plot(strain_per + mini, stress, '-', color = 'b',linestyle='dashed',label='16 D_with seal')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})



import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_2\\Specimen_RawData_3.csv',names = headers, skiprows=skip)

from scipy.interpolate import interp1d

time1 = np.arange(0,56)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

#stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(5),mode = 'same')/5
dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100

# plt.plot(strain_per, stress, '-', color = 'blue', label='21 days', lw=1) 

plt.plot(strain_per, stress, '-', color = 'orange',label='21 D_with seal')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.interpolate import interp1d

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_2\\Specimen_RawData_4.csv',names = headers, skiprows=skip)

from scipy.interpolate import interp1d

time1 = np.arange(0,76)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))


#stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(10),mode = 'same')/10

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100


# plt.plot(strain_per, stress, '-', color = 'blue', label='21 days_withiut sealing', lw=1) 


plt.plot(strain_per, stress, '-', color = 'orange',linestyle='dashed', label='21 D_without seal')
plt.legend(loc='best',fontsize=14)
plt.title('Aging Strengths', fontdict={'fontsize': 16})
plt.xlabel('% Strain',fontdict={'fontsize': 14})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 14})

# n = 100  # the larger n is, the smoother curve will be
# b = [1.0 / n] * n
# a = 1
# yy = lfilter(b,a, df['16 D_without seal', '16 D_with seal', '21 D_without seal', '21 D_with seal' ])

plt.show()
# Out:
# C:\Users\t470\AppData\Local\Temp/ipykernel_14676/750807374.py:81: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per + mini, stress, '-', color = 'b',linestyle='dashed',label='16 D_with seal')
# C:\Users\t470\AppData\Local\Temp/ipykernel_14676/750807374.py:168: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', color = 'orange',linestyle='dashed', label='21 D_without seal')

# %% [markdown]
# # Comments
# 1. Max/peak flexural stress for 21 days is higher in case of sealed sample that without sealed sample.
# 2. For a certain strain (say 5%) 16 days flexural stress is higher than 21 days flexural stress.
# 3. For 16 days sample peak flexual stress is more than 21 days sample.
# 4. Max/peak flexural stress for 16 days is nearly similar in both sealed and without sealed sample.

# %%
#
