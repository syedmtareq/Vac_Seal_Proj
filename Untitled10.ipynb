# %%
# Arbitrary sample 3

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_3\\A7_withouSeal_7(0.42N,0.29).csv')
df
# Out:
#          (s)  Extension      (N)
# 0      0.000    0.00000 -0.20356
# 1      0.026    0.00000 -0.21923
# 2      0.052    0.00006 -0.16813
# 3      0.088    0.00011 -0.19792
# 4      0.114    0.00017 -0.26939
# ...      ...        ...      ...
# 1680  43.690    0.36408 -0.21108
# 1681  43.716    0.36431 -0.25184
# 1682  43.742    0.36454 -0.25717
# 1683  43.768    0.36476 -0.22676
# 1684  43.780    0.36488 -0.19008
#
# [1685 rows x 3 columns]

# %%
from scipy.signal import lfilter

plt.rcParams["figure.figsize"] = (10,4)

# plt.plot(df.Extension, df['16 D_without seal'])
n = 100  # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
yy = lfilter(b,a, df["(N)"])
#plt.plot(df.Extension, yy, linewidth=2, linestyle="-", color="blue")7 D_1_with
plt.plot(df["Extension"],yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_without')


plt.legend(loc='best',fontsize=14)
plt.title('Load vs Extension', fontdict={'fontsize': 16})
plt.xlabel('Extension (mm)',fontdict={'fontsize': 14})
plt.ylabel('Load(MPa)',fontdict={'fontsize': 14})

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '(N)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6468/628176979.py in <module>
#       7 b = [1.0 / n] * n
#       8 a = 1
# ----> 9 yy = lfilter(b,a, df["(N)"])
#      10 #plt.plot(df.Extension, yy, linewidth=2, linestyle="-", color="blue")7 D_1_with
#      11 plt.plot(df["Extension"],yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_without')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: '(N)'

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

df1 = pd.read_csv('D:\Yang\Practice\ArbitrarySample_3\\A7_withoutSeal_VT_Layer.csv')
df1
# Out:
#         (s)  Extension  Without   VT10_S   VT10_D   VT20_S   VT20_D   VT40_S  \
# 0     0.000    0.00000 -6.47160 -0.22065  0.40884 -0.09637 -6.42332 -0.20356
# 1     0.026    0.00000 -6.48132 -0.20842  0.36684 -0.06345 -6.38727 -0.21923
# 2     0.052    0.00006 -6.52208 -0.15983  0.43330 -0.03618 -6.36940 -0.16813
# 3     0.088    0.00011 -6.51612 -0.09368  0.50164 -0.05906 -6.35122 -0.19792
# 4     0.114    0.00017 -6.46784 -0.12347  0.52985 -0.11110 -6.38696 -0.26939
# ...     ...        ...      ...      ...      ...      ...      ...      ...
# 4584    NaN        NaN      NaN  2.19576      NaN      NaN      NaN      NaN
# 4585    NaN        NaN      NaN  2.18667      NaN      NaN      NaN      NaN
# 4586    NaN        NaN      NaN  2.17287      NaN      NaN      NaN      NaN
# 4587    NaN        NaN      NaN  2.21457      NaN      NaN      NaN      NaN
# 4588    NaN        NaN      NaN  2.21958      NaN      NaN      NaN      NaN
#
#        VT40_D
# 0    -0.14792
# 1    -0.06171
# 2    -0.04164
# 3    -0.03475
# 4     0.03422
# ...       ...
# 4584      NaN
# 4585      NaN
# 4586      NaN
# 4587      NaN
# 4588      NaN
#
# [4589 rows x 9 columns]

# %%
from scipy.signal import lfilter

plt.rcParams["figure.figsize"] = (16,10)

# plt.plot(df.Extension, df['16 D_without seal'])
n = 100  # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
yy = lfilter(b,a, df1['Without'])
#plt.plot(df.Extension, yy, linewidth=2, linestyle="-", color="blue")7 D_1_with
plt.plot(df1.Extension, yy, linewidth=2, linestyle='-', color="blue", label='Without')

# %%
from scipy.signal import lfilter

plt.rcParams["figure.figsize"] = (16,10)

# plt.plot(df.Extension, df['16 D_without seal'])
n = 1  # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
yy = lfilter(b,a, df1['Without'])
#plt.plot(df.Extension, yy, linewidth=2, linestyle="-", color="blue")7 D_1_with
plt.plot(df1.Extension, yy, linewidth=2, linestyle='-', color="yellow", label='Without')



# plt.plot(df.Extension, df['16 D_with seal'])
n = 100  # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
yy = lfilter(b,a, df1['VT10_S'])
#plt.plot(df.Extension, yy, linewidth=2, linestyle="-", color="red")
plt.plot(df1.Extension, yy, linewidth=2, linestyle="dashed", color="blue", label='VT10_S' )


# plt.plot(df.Extension, df['21 D_without seal'])
n = 1  # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
yy = lfilter(b,a, df1['VT10_D'])
plt.plot(df1.Extension, yy, linewidth=2, linestyle='-', color="blue",label='VT10_D' )





# plt.plot(df.Extension, df['21 D_with seal'])
n = 10  # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
yy = lfilter(b,a, df1['VT20_S'])
plt.plot(df1.Extension, yy, linewidth=2, linestyle="dashed", color="green", label='VT20_S' )


# plt.plot(df.Extension, df['21 D_with seal'])
n = 5  # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
yy = lfilter(b,a, df1['VT20_D'])
plt.plot(df1.Extension, yy, linewidth=2, linestyle="-", color="green", label='VT20_D' )


# plt.plot(df.Extension, df['21 D_with seal'])
n = 2  # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
yy = lfilter(b,a, df1['VT40_S'])
plt.plot(df1.Extension, yy, linewidth=2, linestyle="dashed", color="orange", label='VT40_S' )


# plt.plot(df.Extension, df['21 D_with seal'])
n = 100  # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
yy = lfilter(b,a, df1['VT40_D'])
plt.plot(df1.Extension, yy, linewidth=2, linestyle="-", color="orange", label='VT40_D' )

plt.legend(loc='best',fontsize=14)
plt.title('Load vs Extension', fontdict={'fontsize': 16})
plt.xlabel('Extension (mm)',fontdict={'fontsize': 14})
plt.ylabel('Load(N)',fontdict={'fontsize': 14})

# plt.ylim(0,1000)
plt.xlim(0.001,0.4)

# plt.legend()

# plt.plot(strain_per, stress, '-', color = 'g',linestyle='dashed', label='21 Days_without sealing')
# plt.legend(loc='best',fontsize=14)
# plt.title('Aging Strengths', fontdict={'fontsize': 16})
# plt.xlabel('% Strain',fontdict={'fontsize': 14})
# plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 14})

plt.show()

# %%
# Stress

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_3\\A7_Without(3.5N, 0.9)).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d
plt.rcParams["figure.figsize"] = (10,4)
time1 = np.arange(0,240)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
# M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
#E = 1.4177*(10**-6)*(320**3.25)/1000
E=106
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='-', color = 'yellow',label='A7_without')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.show()
# Out:
# C:\Users\t470\AppData\Local\Temp/ipykernel_6468/2652354351.py:37: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='-', color = 'yellow',label='A7_without')

# %%
df.describe()
# Out:
#               time    extension         load
# count  1685.000000  1685.000000  1685.000000
# mean     21.901974     0.182551    -0.123732
# std      12.650626     0.105437     0.163401
# min       0.000000     0.000000    -0.333660
# 25%      10.956000     0.091350    -0.226130
# 50%      21.902000     0.182520    -0.189450
# 75%      32.848000     0.273760    -0.095400
# max      43.780000     0.364880     0.449760

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_3\\A7_VT10_S_11(1.35 N, 0.194).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

time1 = np.arange(0,314)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='dashed', color = 'blue',label='A7_VT0_S')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.show()
# Out:
# C:\Users\t470\AppData\Local\Temp/ipykernel_6468/417819146.py:35: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='dashed', color = 'blue',label='A7_VT0_S')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_3\\A7_VT10_D_10(2.3 N, 0.94).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

time1 = np.arange(0,314)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)
plt.rcParams["figure.figsize"] = (10,4)
f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle="dashed", color="orange", label='7 D_2_without' )
plt.plot(strain_per, stress, '-', linestyle='-', color = 'blue',label='A7_VT10_D')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.show()
# Out:
# C:\Users\t470\AppData\Local\Temp/ipykernel_6468/3565042971.py:35: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='-', color = 'blue',label='A7_VT10_D')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_3\\A7_VT20_S_9(2.67 N, 0.83).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

time1 = np.arange(0,314)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)
plt.rcParams["figure.figsize"] = (10,4)
f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='dashed', color = 'g',label='A7_VT20_S')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.show()
# Out:
# C:\Users\t470\AppData\Local\Temp/ipykernel_6468/2323235313.py:35: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='dashed', color = 'g',label='A7_VT20_S')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_3\\A7_VT10_D_10(2.3 N, 0.94).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

time1 = np.arange(0,314)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)
plt.rcParams["figure.figsize"] = (10,4)
f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle="dashed", color="orange", label='7 D_2_without' )
plt.plot(strain_per, stress, '-', linestyle='-', color = 'blue',label='A7_VT20_D')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.show()
# Out:
# C:\Users\t470\AppData\Local\Temp/ipykernel_6468/582680312.py:35: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='-', color = 'blue',label='A7_VT20_D')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_3\\A7_VT40_D_4(4N, 0.45).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d
plt.rcParams["figure.figsize"] = (10,4)
time1 = np.arange(0,314)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='dashed', color = 'orange',label='A7_VT40_S')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.show()
# Out:
# C:\Users\t470\AppData\Local\Temp/ipykernel_6468/9708433.py:35: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='dashed', color = 'orange',label='A7_VT40_S')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_3\\A7_Without(3.5N, 0.9).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

time1 = np.arange(0,314)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)
plt.rcParams["figure.figsize"] = (10,4)
f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle="dashed", color="orange", label='7 D_2_without' )
plt.plot(strain_per, stress, '-', linestyle='-', color = 'orange',label='A7_VT40_D')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.show()
# Out:
# C:\Users\t470\AppData\Local\Temp/ipykernel_6468/1143934775.py:35: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='-', color = 'orange',label='A7_VT40_D')

# %%
##### Combining the plot

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
plt.rcParams["figure.figsize"] = (16,6)

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_3\\A7_withouSeal_7(0.42N,0.29).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

time1 = np.arange(0,314)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='-', color = 'yellow',label='A7_without')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
#plt.show()
########################################################################################
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_3\\A7_VT10_S_11(1.35 N, 0.194).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

time1 = np.arange(0,314)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='dashed', color = 'blue',label='A7_VT10_S')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
#plt.show()
######################################################################################

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_3\\A7_VT10_D_10(2.3 N, 0.94).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

time1 = np.arange(0,314)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle="dashed", color="orange", label='7 D_2_without' )
plt.plot(strain_per, stress, '-', linestyle='-', color = 'blue',label='A7_VT10_D')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
#plt.show()
#################################################################################

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_3\\A7_VT20_S_9(2.67 N, 0.83).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

time1 = np.arange(0,314)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='dashed', color = 'g',label='A7_VT20_S')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
# plt.show()
#######################################################################################


import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_3\\A7_VT20_D_6(3.56N, .77).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

time1 = np.arange(0,100)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle="dashed", color="orange", label='7 D_2_without' )
plt.plot(strain_per, stress, '-', linestyle='-', color = 'g',label='A7_VT20_D')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
# plt.show()

###################################################################################

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_3\\A7_VT40_D_4(4N, 0.45).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

time1 = np.arange(0,314)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='dashed', color = 'orange',label='A7_VT40_S')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
#plt.show()
#####################################################################################

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_3\\A7_Without(3.5N, 0.9).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

time1 = np.arange(0,314)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle="dashed", color="orange", label='7 D_2_without' )
plt.plot(strain_per, stress, '-', linestyle='-', color = 'orange',label='A7_VT40_D')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.ylim(0,1000)
plt.xlim(0,.005)
plt.show()
# Out:
# C:\Users\t470\AppData\Local\Temp/ipykernel_6468/1260762557.py:36: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='-', color = 'yellow',label='A7_without')
# C:\Users\t470\AppData\Local\Temp/ipykernel_6468/1260762557.py:77: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='dashed', color = 'blue',label='A7_VT10_S')
# C:\Users\t470\AppData\Local\Temp/ipykernel_6468/1260762557.py:119: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='-', color = 'blue',label='A7_VT10_D')
# C:\Users\t470\AppData\Local\Temp/ipykernel_6468/1260762557.py:161: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='dashed', color = 'g',label='A7_VT20_S')
# C:\Users\t470\AppData\Local\Temp/ipykernel_6468/1260762557.py:204: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='-', color = 'g',label='A7_VT20_D')
# C:\Users\t470\AppData\Local\Temp/ipykernel_6468/1260762557.py:247: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='dashed', color = 'orange',label='A7_VT40_S')
# C:\Users\t470\AppData\Local\Temp/ipykernel_6468/1260762557.py:289: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='-', color = 'orange',label='A7_VT40_D')

# %%
# Out:
#   File "C:\Users\t470\AppData\Local\Temp/ipykernel_6468/3094814021.py", line 14
#     df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_3\\import matplotlib.pyplot as plt
#                                                                                          ^
# SyntaxError: EOL while scanning string literal

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
plt.rcParams["figure.figsize"] = (16,6)

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_3\\A7_VT20_D_4(4N, 0.45).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

#time1 = np.arange(0,314)
time1 = np.arange(0,100)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='-', color = 'yellow',label='A7_without')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
#plt.show()
########################################################################################
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_3\\A7_VT10_D_10(2.3 N, 0.94).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

time1 = np.arange(0,314)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='dashed', color = 'blue',label='A7_VT10_S')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
#plt.show()
######################################################################################

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_3\\A7_VT10_S_11(1.35 N, 0.194).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

time1 = np.arange(0,314)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle="dashed", color="orange", label='7 D_2_without' )
plt.plot(strain_per, stress, '-', linestyle='-', color = 'blue',label='A7_VT10_D')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
#plt.show()
#################################################################################

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_3\\A7_VT40_D_4(4N, 0.45).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

time1 = np.arange(0,314)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='dashed', color = 'g',label='A7_VT20_S')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
# plt.show()
#######################################################################################


import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,5)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_3\\A7_VT40_D_8(5.5 N, 0.17).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d
time1 = np.arange(0,50)
#time1 = np.arange(0,100)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle="dashed", color="orange", label='7 D_2_without' )
plt.plot(strain_per, stress, '-', linestyle='-', color = 'g',label='A7_VT20_D')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
# plt.show()

###################################################################################

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_3\\A7_withouSeal_7(0.42N,0.29).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

time1 = np.arange(0,314)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='dashed', color = 'orange',label='A7_VT40_S')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
#plt.show()
#####################################################################################

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_3\\A7_VT20_S_9(2.67 N, 0.83).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

time1 = np.arange(0,314)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle="dashed", color="orange", label='7 D_2_without' )
plt.plot(strain_per, stress, '-', linestyle='-', color = 'orange',label='A7_VT40_D')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.ylim(0,1000)
plt.xlim(0,.0035)
plt.show()
# Out:
# C:\Users\t470\AppData\Local\Temp/ipykernel_6468/2802180660.py:37: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='-', color = 'yellow',label='A7_without')
# C:\Users\t470\AppData\Local\Temp/ipykernel_6468/2802180660.py:78: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='dashed', color = 'blue',label='A7_VT10_S')
# C:\Users\t470\AppData\Local\Temp/ipykernel_6468/2802180660.py:120: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='-', color = 'blue',label='A7_VT10_D')
# C:\Users\t470\AppData\Local\Temp/ipykernel_6468/2802180660.py:162: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='dashed', color = 'g',label='A7_VT20_S')
# C:\Users\t470\AppData\Local\Temp/ipykernel_6468/2802180660.py:205: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='-', color = 'g',label='A7_VT20_D')
# C:\Users\t470\AppData\Local\Temp/ipykernel_6468/2802180660.py:248: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='dashed', color = 'orange',label='A7_VT40_S')
# C:\Users\t470\AppData\Local\Temp/ipykernel_6468/2802180660.py:290: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='-', color = 'orange',label='A7_VT40_D')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_3\\A7_VT40_D.csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

time1 = np.arange(0,314)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='-', color = 'blue',label='7 D_1_with')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
## plt.show()



import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_2\\A7_VT40_D.csv',names = headers, skiprows=skip)

from scipy.interpolate import interp1d

time1 = np.arange(0,66)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(10),mode = 'same')/10

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100

# plt.plot(strain_per, stress, '-', color = 'blue', label='7 D_2_without', lw=1) 
plt.plot(strain_per, stress, '-', linestyle='dashed', color = 'blue',label='7 D_1_without')
#plt.plot(strain_per, stress, '-', color = 'b',label='7 D_2')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
#  plt.show()


import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,5)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_2\\Specimen_RawData_7.csv',names = headers, skiprows=skip)

from scipy.interpolate import interp1d

time1 = np.arange(0,86)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(5),mode = 'same')/5

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100

# plt.plot(strain_per, stress, '-', color = 'blue', label='7 days', lw=1) 
plt.plot(strain_per, stress, '-', linestyle='-', color = 'orange',label='7 D_2_with')
#plt.plot(strain_per, stress, '-', color = 'r',label='7D_2_Sealed')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
##  plt.show()

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_2\\Specimen_RawData_8.csv',names = headers, skiprows=skip)

from scipy.interpolate import interp1d

time1 = np.arange(0,120)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(20),mode = 'same')/20

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100

# plt.plot(strain_per, stress, '-', color = 'blue', label='7 days', lw=1) 
#plt.plot(strain_per, stress, '-', linestyle='dashed', color = 'orange',label='7 D_2_without'
plt.plot(strain_per, stress, '-', linestyle='dashed', color = 'orange',label='7 D_2_without')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.xlim(0,.1)
plt.show()
# Out:
# C:\Users\t470\AppData\Local\Temp/ipykernel_6468/2099248705.py:35: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='-', color = 'blue',label='7 D_1_with')
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6468/2099248705.py in <module>
#      54 skip = np.arange(0,1)
#      55 headers = ['time', 'extension', 'load']
# ---> 56 df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_2\\A7_VT40_D.csv',names = headers, skiprows=skip)
#      57
#      58 from scipy.interpolate import interp1d
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\Yang\\Practice\\ArbitrarySample_2\\A7_VT40_D.csv'
