# %%
## Project_part3

# %%
## Library upload

import  pandas as pd
import numpy as np

# %%
## Data upload 

Air_Quality = pd.read_csv('D:\Data_A\Project\Real_Combine.csv')
Air_Quality
# Out:
#          T    TM    Tm     SLP     H   VV     V    VM      PM 2.5
# 0      7.4   9.8   4.8  1017.6  93.0  0.5   4.3   9.4  219.720833
# 1      7.8  12.7   4.4  1018.5  87.0  0.6   4.4  11.1  182.187500
# 2      6.7  13.4   2.4  1019.4  82.0  0.6   4.8  11.1  154.037500
# 3      8.6  15.5   3.3  1018.7  72.0  0.8   8.1  20.6  223.208333
# 4     12.4  20.9   4.4  1017.3  61.0  1.3   8.7  22.2  200.645833
# ...    ...   ...   ...     ...   ...  ...   ...   ...         ...
# 1088  18.1  24.0  11.2  1015.4  56.0  1.8  15.9  25.9  288.416667
# 1089  17.8  25.0  10.7  1015.8  54.0  2.3   9.4  22.2  256.833333
# 1090  13.9  24.5  11.4  1015.0  95.0  0.6   8.7  14.8  169.000000
# 1091  16.3  23.0   9.8  1016.9  78.0  1.1   7.4  16.5  186.041667
# 1092  16.3  23.4   9.0  1017.3  68.0  1.3   7.8  18.3  185.583333
#
# [1093 rows x 9 columns]

# %%
# # Data cleaning 

Air_Quality.isnull().sum()

Air_Quality[Air_Quality['PM 2.5'].isnull()]
# Out:
#         T    TM    Tm     SLP     H   VV    V    VM  PM 2.5
# 184  14.3  19.2  10.9  1020.5  91.0  1.6  4.8  11.1     NaN

# %%
# # Data update

Air_Quality_Updated = Air_Quality.interpolate()
Air_Quality_Updated
# Out:
#          T    TM    Tm     SLP     H   VV     V    VM      PM 2.5
# 0      7.4   9.8   4.8  1017.6  93.0  0.5   4.3   9.4  219.720833
# 1      7.8  12.7   4.4  1018.5  87.0  0.6   4.4  11.1  182.187500
# 2      6.7  13.4   2.4  1019.4  82.0  0.6   4.8  11.1  154.037500
# 3      8.6  15.5   3.3  1018.7  72.0  0.8   8.1  20.6  223.208333
# 4     12.4  20.9   4.4  1017.3  61.0  1.3   8.7  22.2  200.645833
# ...    ...   ...   ...     ...   ...  ...   ...   ...         ...
# 1088  18.1  24.0  11.2  1015.4  56.0  1.8  15.9  25.9  288.416667
# 1089  17.8  25.0  10.7  1015.8  54.0  2.3   9.4  22.2  256.833333
# 1090  13.9  24.5  11.4  1015.0  95.0  0.6   8.7  14.8  169.000000
# 1091  16.3  23.0   9.8  1016.9  78.0  1.1   7.4  16.5  186.041667
# 1092  16.3  23.4   9.0  1017.3  68.0  1.3   7.8  18.3  185.583333
#
# [1093 rows x 9 columns]

# %%
# # Data pattern

Air_Quality_Updated.head()
# Out:
#       T    TM   Tm     SLP     H   VV    V    VM      PM 2.5
# 0   7.4   9.8  4.8  1017.6  93.0  0.5  4.3   9.4  219.720833
# 1   7.8  12.7  4.4  1018.5  87.0  0.6  4.4  11.1  182.187500
# 2   6.7  13.4  2.4  1019.4  82.0  0.6  4.8  11.1  154.037500
# 3   8.6  15.5  3.3  1018.7  72.0  0.8  8.1  20.6  223.208333
# 4  12.4  20.9  4.4  1017.3  61.0  1.3  8.7  22.2  200.645833

# %%
Air_Quality_Updated.tail()
# Out:
#          T    TM    Tm     SLP     H   VV     V    VM      PM 2.5
# 1088  18.1  24.0  11.2  1015.4  56.0  1.8  15.9  25.9  288.416667
# 1089  17.8  25.0  10.7  1015.8  54.0  2.3   9.4  22.2  256.833333
# 1090  13.9  24.5  11.4  1015.0  95.0  0.6   8.7  14.8  169.000000
# 1091  16.3  23.0   9.8  1016.9  78.0  1.1   7.4  16.5  186.041667
# 1092  16.3  23.4   9.0  1017.3  68.0  1.3   7.8  18.3  185.583333

# %%
# # Statistical analysis of data 

Air_Quality_Updated.describe()
# Out:
#                  T           TM           Tm          SLP            H  \
# count  1093.000000  1093.000000  1093.000000  1093.000000  1093.000000
# mean     26.009241    32.482251    19.460201  1008.081885    62.918573
# std       7.237401     6.679078     7.438653     7.529237    15.709816
# min       6.700000     9.800000     0.000000   991.500000    20.000000
# 25%      19.300000    27.800000    12.100000  1001.100000    54.000000
# 50%      28.200000    34.200000    21.200000  1008.100000    64.000000
# 75%      31.700000    37.000000    26.000000  1015.000000    74.000000
# max      38.500000    45.500000    32.700000  1023.200000    98.000000
#
#                 VV            V           VM       PM 2.5
# count  1093.000000  1093.000000  1093.000000  1093.000000
# mean      2.003111     6.751510    15.805124   109.193333
# std       0.747541     3.841137     7.308435    84.494886
# min       0.300000     0.400000     1.900000     0.000000
# 25%       1.600000     3.700000    11.100000    41.875000
# 50%       1.900000     6.500000    14.800000    83.458333
# 75%       2.600000     9.100000    18.300000   158.291667
# max       5.800000    24.400000    57.600000   404.500000

# %%
# # Data visualization 

# from matplotlib import pyplot as plt 
# import seaborn as sns
# sns.heatmap(Air_Quality_Updated.isnull(), yticklabels=False)

# %%
# # Pairplot

# sns.pairplot(Air_Quality_Updated)
# plt.savefig("pairplot.png")

# %%
# # # Data outlayers using boxplot

# import matplotlib.pyplot as plt

# a4_dims=(11.7, 8.27)
# flg, ax= plt.subplots(figsize=a4_dims)
# g=sns.boxplot(data=Air_Quality_Updated, linewidth=2.5, ax=ax)
# g.set_yscale("log")
# plt.savefig("boxplot.png")
# plt.show()

# %%
# # Data normalization 

#Air_Quality_Updated = Air_Quality_Updated.apply(lambda x: (x-x.min(axis=0)) / (x.max(axis=0)-x.min(axis=0)))

#Air_Quality_Updated
# Out:
#              T        TM        Tm       SLP         H        VV         V  \
# 0     0.022013  0.000000  0.146789  0.823344  0.935897  0.036364  0.162500
# 1     0.034591  0.081232  0.134557  0.851735  0.858974  0.054545  0.166667
# 2     0.000000  0.100840  0.073394  0.880126  0.794872  0.054545  0.183333
# 3     0.059748  0.159664  0.100917  0.858044  0.666667  0.090909  0.320833
# 4     0.179245  0.310924  0.134557  0.813880  0.525641  0.181818  0.345833
# ...        ...       ...       ...       ...       ...       ...       ...
# 1088  0.358491  0.397759  0.342508  0.753943  0.461538  0.272727  0.645833
# 1089  0.349057  0.425770  0.327217  0.766562  0.435897  0.363636  0.375000
# 1090  0.226415  0.411765  0.348624  0.741325  0.961538  0.054545  0.345833
# 1091  0.301887  0.369748  0.299694  0.801262  0.743590  0.145455  0.291667
# 1092  0.301887  0.380952  0.275229  0.813880  0.615385  0.181818  0.308333
#
#             VM    PM 2.5
# 0     0.134650  0.543191
# 1     0.165171  0.450402
# 2     0.165171  0.380810
# 3     0.335727  0.551813
# 4     0.364452  0.496034
# ...        ...       ...
# 1088  0.430880  0.713020
# 1089  0.364452  0.634940
# 1090  0.231598  0.417800
# 1091  0.262118  0.459930
# 1092  0.294434  0.458797
#
# [1093 rows x 9 columns]

# %%
# # Variance or co-variance

# In[77]:


#Air_Quality_Updated.corr()
# Out:
#                T        TM        Tm       SLP         H        VV         V  \
# T       1.000000  0.967570  0.953703 -0.881698 -0.510593  0.640738  0.302349
# TM      0.967570  1.000000  0.891970 -0.823447 -0.588017  0.606746  0.293309
# Tm      0.953703  0.891970  1.000000 -0.917557 -0.288647  0.577382  0.296546
# SLP    -0.881698 -0.823447 -0.917557  1.000000  0.242307 -0.518015 -0.330155
# H      -0.510593 -0.588017 -0.288647  0.242307  1.000000 -0.465514 -0.380805
# VV      0.640738  0.606746  0.577382 -0.518015 -0.465514  1.000000  0.377029
# V       0.302349  0.293309  0.296546 -0.330155 -0.380805  0.377029  1.000000
# VM      0.288292  0.297590  0.267249 -0.311231 -0.362632  0.342650  0.775715
# PM 2.5 -0.632160 -0.569334 -0.674270  0.623910  0.139859 -0.574058 -0.268899
#
#               VM    PM 2.5
# T       0.288292 -0.632160
# TM      0.297590 -0.569334
# Tm      0.267249 -0.674270
# SLP    -0.311231  0.623910
# H      -0.362632  0.139859
# VV      0.342650 -0.574058
# V       0.775715 -0.268899
# VM      1.000000 -0.216420
# PM 2.5 -0.216420  1.000000

# %%
new_data = pd.DataFrame(data = Air_Quality_Updated)
# new_data = pd.concat([DF, DF[['target']]], axis = 1)
display(new_data)
# Out:
#              T        TM        Tm       SLP         H        VV         V  \
# 0     0.022013  0.000000  0.146789  0.823344  0.935897  0.036364  0.162500
# 1     0.034591  0.081232  0.134557  0.851735  0.858974  0.054545  0.166667
# 2     0.000000  0.100840  0.073394  0.880126  0.794872  0.054545  0.183333
# 3     0.059748  0.159664  0.100917  0.858044  0.666667  0.090909  0.320833
# 4     0.179245  0.310924  0.134557  0.813880  0.525641  0.181818  0.345833
# ...        ...       ...       ...       ...       ...       ...       ...
# 1088  0.358491  0.397759  0.342508  0.753943  0.461538  0.272727  0.645833
# 1089  0.349057  0.425770  0.327217  0.766562  0.435897  0.363636  0.375000
# 1090  0.226415  0.411765  0.348624  0.741325  0.961538  0.054545  0.345833
# 1091  0.301887  0.369748  0.299694  0.801262  0.743590  0.145455  0.291667
# 1092  0.301887  0.380952  0.275229  0.813880  0.615385  0.181818  0.308333
#
#             VM    PM 2.5
# 0     0.134650  0.543191
# 1     0.165171  0.450402
# 2     0.165171  0.380810
# 3     0.335727  0.551813
# 4     0.364452  0.496034
# ...        ...       ...
# 1088  0.430880  0.713020
# 1089  0.364452  0.634940
# 1090  0.231598  0.417800
# 1091  0.262118  0.459930
# 1092  0.294434  0.458797
#
# [1093 rows x 9 columns]

# %%
## Decision tree

# %%
# X_train, X_test, y_train, y_test = train_test_split(
#     new_data.iloc[:,:-1],
#     new_data.iloc[:,-1],
#     test_size=0.3,
#     random_state=0)

# %%
# Traning model with all features 

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(Air_Quality_Updated.iloc[:,:-1], Air_Quality_Updated.iloc[:,-1], test_size=0.3, random_state=0)

# %%
X_train
# Out:
#             T        TM        Tm       SLP         H        VV         V  \
# 339  0.518868  0.624650  0.489297  0.700315  0.538462  0.127273  0.137500
# 424  0.795597  0.862745  0.660550  0.391167  0.320513  0.436364  0.162500
# 73   0.974843  0.985994  0.932722  0.208202  0.153846  0.290909  0.400000
# 43   0.518868  0.554622  0.510703  0.539432  0.435897  0.290909  0.529167
# 500  0.823899  0.789916  0.840979  0.372240  0.538462  0.290909  0.000000
# ..        ...       ...       ...       ...       ...       ...       ...
# 688  0.742138  0.705882  0.755352  0.498423  0.538462  0.363636  0.300000
# 621  0.962264  0.949580  0.874618  0.186120  0.307692  0.418182  0.375000
# 850  0.814465  0.733894  0.844037  0.255521  0.641026  0.436364  0.425000
# 583  0.632075  0.661064  0.480122  0.725552  0.410256  0.381818  0.175000
# 332  0.559748  0.577031  0.599388  0.735016  0.679487  0.327273  0.112500
#
#            VM
# 339  0.165171
# 424  0.134650
# 73   0.364452
# 43   0.364452
# 500  0.028725
# ..        ...
# 688  0.294434
# 621  0.364452
# 850  0.335727
# 583  0.134650
# 332  0.102334
#
# [765 rows x 8 columns]

# %%
X_test
# Out:
#             T        TM        Tm       SLP         H        VV         V  \
# 77   0.792453  0.862745  0.816514  0.331230  0.525641  0.290909  0.545833
# 336  0.588050  0.652661  0.568807  0.656151  0.653846  0.127273  0.020833
# 562  0.157233  0.229692  0.195719  0.813880  0.717949  0.090909  0.166667
# 189  0.157233  0.305322  0.198777  0.813880  0.884615  0.000000  0.020833
# 92   0.855346  0.823529  0.850153  0.116719  0.538462  0.290909  0.354167
# ..        ...       ...       ...       ...       ...       ...       ...
# 282  0.918239  0.859944  0.905199  0.151420  0.333333  0.290909  0.554167
# 664  0.770440  0.753501  0.856269  0.198738  0.705128  0.436364  0.362500
# 352  0.305031  0.470588  0.244648  0.741325  0.474359  0.181818  0.091667
# 155  0.537736  0.579832  0.562691  0.694006  0.653846  0.236364  0.037500
# 690  0.732704  0.733894  0.688073  0.422713  0.551282  0.418182  0.108333
#
#            VM
# 77   0.335727
# 336  0.028725
# 562  0.199282
# 189  0.102334
# 92   0.231598
# ..        ...
# 282  0.464991
# 664  0.231598
# 352  0.231598
# 155  0.028725
# 690  0.102334
#
# [328 rows x 8 columns]

# %%
from sklearn.tree import DecisionTreeRegressor
reg_decision_model=DecisionTreeRegressor()
# fit independent varaibles to the dependent variables
reg_decision_model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
reg_decision_model.score(X_train,y_train)
# Out:
# 1.0

# %%
reg_decision_model.score(X_test,y_test)
# Out:
# 0.5177729593059224

# %%
## Decision Tree Model Evaluation

# %%
import seaborn as sns
prediction=reg_decision_model.predict(X_test)
# checking difference between labled y and predicted y
sns.distplot(y_test-prediction)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='PM 2.5', ylabel='Density'>

# %%
#checking predicted y and labeled y using a scatter plot.
import matplotlib.pyplot as plt
plt.scatter(y_test,prediction)

# %%
## Analysis using KNN model

# %%
new_data['target'] = pd.qcut(new_data['PM 2.5'], 3, labels=list('ABC'))
display(new_data.head())

# print(new_data['target'][0:50])
# Out:
#           T        TM        Tm       SLP         H        VV         V  \
# 0  0.022013  0.000000  0.146789  0.823344  0.935897  0.036364  0.162500
# 1  0.034591  0.081232  0.134557  0.851735  0.858974  0.054545  0.166667
# 2  0.000000  0.100840  0.073394  0.880126  0.794872  0.054545  0.183333
# 3  0.059748  0.159664  0.100917  0.858044  0.666667  0.090909  0.320833
# 4  0.179245  0.310924  0.134557  0.813880  0.525641  0.181818  0.345833
#
#          VM    PM 2.5 target
# 0  0.134650  0.543191      C
# 1  0.165171  0.450402      C
# 2  0.165171  0.380810      C
# 3  0.335727  0.551813      C
# 4  0.364452  0.496034      C

# %%
new_data = new_data.drop(labels = ['PM 2.5'], axis  = 1)
new_data.head()
# Out:
#           T        TM        Tm       SLP         H        VV         V  \
# 0  0.022013  0.000000  0.146789  0.823344  0.935897  0.036364  0.162500
# 1  0.034591  0.081232  0.134557  0.851735  0.858974  0.054545  0.166667
# 2  0.000000  0.100840  0.073394  0.880126  0.794872  0.054545  0.183333
# 3  0.059748  0.159664  0.100917  0.858044  0.666667  0.090909  0.320833
# 4  0.179245  0.310924  0.134557  0.813880  0.525641  0.181818  0.345833
#
#          VM target
# 0  0.134650      C
# 1  0.165171      C
# 2  0.165171      C
# 3  0.335727      C
# 4  0.364452      C

# %%
new_x = new_data.iloc[:,:8]
new_y = new_data.iloc[:,8]

# %%
 
## splitting the dataset
 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(new_x, new_y, random_state=11, test_size=.3, shuffle=False)

# %%
X_train
# Out:
#             T        TM        Tm       SLP         H        VV         V  \
# 0    0.022013  0.000000  0.146789  0.823344  0.935897  0.036364  0.162500
# 1    0.034591  0.081232  0.134557  0.851735  0.858974  0.054545  0.166667
# 2    0.000000  0.100840  0.073394  0.880126  0.794872  0.054545  0.183333
# 3    0.059748  0.159664  0.100917  0.858044  0.666667  0.090909  0.320833
# 4    0.179245  0.310924  0.134557  0.813880  0.525641  0.181818  0.345833
# ..        ...       ...       ...       ...       ...       ...       ...
# 760  0.503145  0.577031  0.391437  0.826498  0.461538  0.418182  0.083333
# 761  0.503145  0.582633  0.397554  0.848580  0.487179  0.381818  0.120833
# 762  0.575472  0.593838  0.458716  0.763407  0.500000  0.290909  0.054167
# 763  0.572327  0.633053  0.464832  0.741325  0.474359  0.290909  0.054167
# 764  0.632075  0.661064  0.480122  0.725552  0.410256  0.381818  0.175000
#
#            VM
# 0    0.134650
# 1    0.165171
# 2    0.165171
# 3    0.335727
# 4    0.364452
# ..        ...
# 760  0.102334
# 761  0.102334
# 762  0.062837
# 763  0.134650
# 764  0.134650
#
# [765 rows x 8 columns]

# %%
y_train
# Out:
# 0      C
# 1      C
# 2      C
# 3      C
# 4      C
#       ..
# 760    B
# 761    B
# 762    A
# 763    A
# 764    A
# Name: target, Length: 765, dtype: category
# Categories (3, object): ['A' < 'B' < 'C']

# %%
X_test
# Out:
#              T        TM        Tm       SLP         H        VV         V  \
# 765   0.534591  0.540616  0.483180  0.643533  0.602564  0.327273  0.200000
# 766   0.525157  0.540616  0.519878  0.627760  0.551282  0.327273  0.262500
# 767   0.553459  0.537815  0.477064  0.637224  0.461538  0.290909  0.400000
# 768   0.553459  0.593838  0.513761  0.608833  0.589744  0.563636  0.270833
# 769   0.493711  0.551821  0.522936  0.712934  0.615385  0.563636  0.245833
# ...        ...       ...       ...       ...       ...       ...       ...
# 1088  0.358491  0.397759  0.342508  0.753943  0.461538  0.272727  0.645833
# 1089  0.349057  0.425770  0.327217  0.766562  0.435897  0.363636  0.375000
# 1090  0.226415  0.411765  0.348624  0.741325  0.961538  0.054545  0.345833
# 1091  0.301887  0.369748  0.299694  0.801262  0.743590  0.145455  0.291667
# 1092  0.301887  0.380952  0.275229  0.813880  0.615385  0.181818  0.308333
#
#             VM
# 765   0.165171
# 766   0.262118
# 767   0.294434
# 768   0.231598
# 769   0.262118
# ...        ...
# 1088  0.430880
# 1089  0.364452
# 1090  0.231598
# 1091  0.262118
# 1092  0.294434
#
# [328 rows x 8 columns]

# %%
y_test
# Out:
# 765     B
# 766     B
# 767     B
# 768     B
# 769     B
#        ..
# 1088    C
# 1089    C
# 1090    C
# 1091    C
# 1092    C
# Name: target, Length: 328, dtype: category
# Categories (3, object): ['A' < 'B' < 'C']

# %%
from sklearn import preprocessing
from sklearn import utils

# %%
from sklearn.datasets  import load_breast_cancer
from sklearn.decomposition import PCA
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import KFold, cross_val_score

# %%
## training the model for different k value

# for k in range (2,15):
#     kfold = KFold(n_splits=10, random_state = 10, shuffle = True)
#     knn = KNeighborsClassifier(n_neighbors=k)
#     scores = cross_val_score(estimator = knn, X = X_train, y = y_train, cv = kfold)
#     print('K = {0:<4}\tMean Accuracy = {1:.2%}\t\tStandard Deviation = {2:.2}'.format(k,scores.mean(), scores.std()))
    
 
knn = KNeighborsClassifier(n_neighbors = 10)
knn.fit(X = X_train, y = y_train)
predicted = knn.predict(X_test)
expected = y_test

 
# print('\n Mismatched Prdiction: ')
# wrong = [(p,e) for (p,e) in zip (predicted,expected) if p!=e]
# print(wrong,"\n\n")

# %%
print('\n Mismatched Prdiction: ')
wrong = [(p,e) for (p,e) in zip (predicted,expected) if p!=e]
print(wrong,"\n\n")


from sklearn.metrics import confusion_matrix
 
confusion  = confusion_matrix(y_true = expected, y_pred = predicted)
confusion_df= pd.DataFrame(confusion, index = range(3), columns = range(3))
sns.heatmap(confusion_df, annot= True, cmap = 'Reds')
plt.show()


# Classification report 
 
 
from sklearn.metrics import classification_report
 
print('\nClassification Report: \n')
print(classification_report(expected, predicted))
# Out:
#  Mismatched Prdiction:
# [('A', 'C'), ('B', 'A'), ('B', 'A'), ('B', 'A'), ('B', 'A'), ('B', 'A'), ('B', 'A'), ('B', 'A'), ('B', 'A'), ('B', 'A'), ('B', 'C'), ('B', 'C'), ('B', 'C'), ('B', 'C'), ('B', 'C'), ('B', 'A'), ('B', 'A'), ('A', 'B'), ('A', 'B'), ('A', 'B'), ('A', 'B'), ('A', 'B'), ('A', 'B'), ('A', 'B'), ('A', 'B'), ('A', 'B'), ('A', 'B'), ('A', 'B'), ('A', 'B'), ('B', 'C'), ('B', 'C'), ('B', 'C'), ('B', 'C'), ('B', 'C'), ('C', 'B'), ('B', 'C'), ('B', 'C'), ('B', 'C'), ('B', 'C'), ('B', 'C'), ('C', 'B'), ('C', 'B'), ('C', 'B'), ('B', 'C'), ('C', 'B'), ('C', 'B'), ('C', 'B'), ('C', 'B'), ('A', 'C'), ('B', 'A'), ('B', 'A'), ('B', 'A'), ('B', 'A'), ('B', 'A'), ('B', 'A'), ('B', 'A'), ('B', 'A'), ('B', 'A'), ('B', 'C'), ('B', 'C'), ('B', 'C'), ('B', 'C'), ('B', 'C'), ('B', 'A'), ('B', 'A'), ('A', 'B'), ('A', 'B'), ('A', 'B'), ('A', 'B'), ('A', 'B'), ('A', 'B'), ('A', 'B'), ('A', 'B'), ('A', 'B'), ('A', 'B'), ('A', 'B'), ('A', 'B'), ('B', 'C'), ('B', 'C'), ('B', 'C'), ('B', 'C'), ('B', 'C'), ('C', 'B'), ('B', 'C'), ('B', 'C'), ('B', 'C'), ('B', 'C'), ('B', 'C')]
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            A       0.79      0.82      0.80       121
#            B       0.57      0.68      0.62       104
#            C       0.89      0.68      0.77       103
#
#     accuracy                           0.73       328
#    macro avg       0.75      0.73      0.73       328
# weighted avg       0.75      0.73      0.74       328

# %%
## Random forest

# %%
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.ensemble import RandomForestClassifier

# %%
# define the model
model = RandomForestClassifier()

# %%
# evaluate the model
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(model, X_train, y_train, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# report performance
print('Accuracy: %.3f' % (mean(n_scores)))
# Out:
# Accuracy: 0.738

# %%
model.fit(X = X_train, y = y_train)
predicted = model.predict(X_test)
expected = y_test

# %%
print('\n Mismatched Prdiction: ')
wrong = [(p,e) for (p,e) in zip (predicted,expected) if p!=e]
print(wrong,"\n\n")



from sklearn.metrics import confusion_matrix
 
confusion  = confusion_matrix(y_true = expected, y_pred = predicted)
confusion_df= pd.DataFrame(confusion, index = range(3), columns = range(3))
sns.heatmap(confusion_df, annot= True, cmap = 'Reds')
plt.show()


# Classification report 
 
 
from sklearn.metrics import classification_report
 
print('\nClassification Report: \n')
print(classification_report(expected, predicted))
# Out:
#  Mismatched Prdiction:
# []
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            A       1.00      1.00      1.00       121
#            B       1.00      1.00      1.00       104
#            C       1.00      1.00      1.00       103
#
#     accuracy                           1.00       328
#    macro avg       1.00      1.00      1.00       328
# weighted avg       1.00      1.00      1.00       328

# %%
#!/usr/bin/env python
# coding: utf-8

# # Library upload

# In[55]:


import  pandas as pd
import numpy as np


# # Data upload 

# In[56]:


Air_Quality = pd.read_csv('D:\Data_A\Project\Real_Combine.csv')
Air_Quality


# # Data cleaning 

# In[57]:


Air_Quality.isnull().sum()


# In[58]:


Air_Quality[Air_Quality['PM 2.5'].isnull()]


# # Data update

# In[60]:


Air_Quality_Updated = Air_Quality.interpolate()
Air_Quality_Updated 


# # Data pattern

# In[62]:


Air_Quality_Updated.head()


# In[65]:


Air_Quality_Updated.tail()


# # Statistical analysis of data 

# In[66]:


Air_Quality_Updated.describe()


# In[67]:


# Data visualization 


# In[68]:


import seaborn as sns
sns.heatmap(Air_Quality_Updated.isnull(), yticklabels=False)


# In[73]:


sns.pairplot(Air_Quality_Updated)
plt.savefig("pairplot.png")


# # Data outlayers using boxplot

# In[74]:


import matplotlib.pyplot as plt

a4_dims=(11.7, 8.27)
flg, ax= plt.subplots(figsize=a4_dims)
g=sns.boxplot(data=Air_Quality_Updated, linewidth=2.5, ax=ax)
g.set_yscale("log")
plt.savefig("boxplot.png")
plt.show()


# In[ ]:





# # Data normalization 

# In[75]:


Air_Quality_Updated = Air_Quality_Updated.apply(lambda x: (x-x.min(axis=0)) / (x.max(axis=0)-x.min(axis=0)))


# In[76]:


Air_Quality_Updated


# In[ ]:





# In[ ]:





# # Variance or co-variance

# In[77]:


Air_Quality_Updated.corr()


# In[ ]:





# # Another method for data normalization 

# In[41]:


from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(Air_Quality_Updated)
New_Data = scaler.transform(Air_Quality_Updated)


# In[14]:


New_Data


# In[ ]:





# In[ ]:
