# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_2\\Specimen_RawData_5.csv')
df
# Out:
#            (s)  Extension  7 D_1_with  7 D_1_without  7 D_2_with  \
# 0        0.000   -1.97795    -0.07967       -0.05616    -0.09879
# 1        0.026   -1.97795    -0.07183       -0.12763    -0.12293
# 2        0.058   -1.97789    -0.06306       -0.09315    -0.14049
# 3        0.084   -1.97784    -0.03077       -0.10224    -0.11823
# 4        0.110   -1.97772    -0.05083       -0.04707    -0.12168
# ...        ...        ...         ...            ...         ...
# 12062  313.618    0.63552     4.75189            NaN         NaN
# 12063  313.644    0.63574     4.68731            NaN         NaN
# 12064  313.670    0.63597     4.73841            NaN         NaN
# 12065  313.696    0.63620     4.74092            NaN         NaN
# 12066  313.700    0.63625     4.74437            NaN         NaN
#
#        7 D_2_without
# 0           -0.18061
# 1           -0.11823
# 2           -0.12952
# 3           -0.14550
# 4           -0.04801
# ...              ...
# 12062            NaN
# ...

# %%
from scipy.signal import lfilter

plt.rcParams["figure.figsize"] = (16,10)

# plt.plot(df.Extension, df['16 D_without seal'])
n = 100  # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
yy = lfilter(b,a, df['7 D_1_with'])
#plt.plot(df.Extension, yy, linewidth=2, linestyle="-", color="blue")7 D_1_with
plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')



# plt.plot(df.Extension, df['16 D_with seal'])
n = 100  # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
yy = lfilter(b,a, df['7 D_1_without'])
#plt.plot(df.Extension, yy, linewidth=2, linestyle="-", color="red")
plt.plot(df.Extension, yy, linewidth=2, linestyle="dashed", color="blue", label='7 D_1_without' )


# plt.plot(df.Extension, df['21 D_without seal'])
n = 100  # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
yy = lfilter(b,a, df['7 D_2_with'])
plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="orange",label='7 D_2_with' )





# plt.plot(df.Extension, df['21 D_with seal'])
n = 100  # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
yy = lfilter(b,a, df['7 D_2_without'])
plt.plot(df.Extension, yy, linewidth=2, linestyle="dashed", color="orange", label='7 D_2_without' )
plt.legend(loc='best',fontsize=14)
plt.title('Load vs Extension', fontdict={'fontsize': 16})
plt.xlabel('Extension (mm)',fontdict={'fontsize': 14})
plt.ylabel('Load(MPa)',fontdict={'fontsize': 14})

# plt.legend()

# plt.plot(strain_per, stress, '-', color = 'g',linestyle='dashed', label='21 Days_without sealing')
# plt.legend(loc='best',fontsize=14)
# plt.title('Aging Strengths', fontdict={'fontsize': 16})
# plt.xlabel('% Strain',fontdict={'fontsize': 14})
# plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 14})

plt.show()

# %%
### VT40_D

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

df1 = pd.read_csv('D:\Yang\Practice\ArbitrarySample_3\\A7_VT40_D.csv')
df1
# Out:
#        Time  Extension  7A_VT40_D_1  7A_VT40_D_2  7A_VT40_D_3  7A_VT40_D_4  \
# 0     0.000    0.43033     -6.42332     -6.47160     -1.98018     -0.09637
# 1     0.026    0.43033     -6.38727     -6.48132     -1.92720     -0.06345
# 2     0.052    0.43038     -6.36940     -6.52208     -1.92814     -0.03618
# 3     0.088    0.43044     -6.35122     -6.51612     -1.93065     -0.05906
# 4     0.114    0.43055     -6.38696     -6.46784     -1.91498     -0.11110
# ...     ...        ...          ...          ...          ...          ...
# 4611    NaN        NaN          NaN          NaN     12.95150          NaN
# 4612    NaN        NaN          NaN          NaN     12.97125          NaN
# 4613    NaN        NaN          NaN          NaN     12.98599          NaN
# 4614    NaN        NaN          NaN          NaN     12.94555          NaN
# 4615    NaN        NaN          NaN          NaN     12.90166          NaN
#
#       7A_VT40_D_5
# 0        -0.14023
# 1        -0.07942
# ...
