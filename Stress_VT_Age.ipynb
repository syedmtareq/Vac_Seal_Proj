# %%
## Stress vs Vacuum Time (VT)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['Time', 'Extension', 'Load']  
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\Arbitrary_sample\Arbitrary_sample_3\arbitrarysample_3\\A7_VT10_S_11(1.35 N, 0.194).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

#plt.rcParams["figure.figsize"] = (10,4)
time1 = np.arange(0,314)

d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
P = f1(time1)
#M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
#E=106
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100

#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='--', color = 'black',label='A1_Without')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20752\4120229749.py:40: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='--', color = 'black',label='A1_Without')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['Time', 'Extension', 'Load']  
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\Arbitrary_sample\Arbitrary_sample_3\arbitrarysample_3\\A7_VT20_D_9(2.67 N, 0.83).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

#plt.rcParams["figure.figsize"] = (10,4)
time1 = np.arange(0,314)

d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
P = f1(time1)
#M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
#E=106
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40000

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100

#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='--', color = 'black',label='VT_10')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20752\3303100005.py:40: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='--', color = 'black',label='VT_10')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['Time', 'Extension', 'Load']  
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\Arbitrary_sample\Arbitrary_sample_3\arbitrarysample_3\\A7_VT20_D_10(2.3 N, 0.94).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

#plt.rcParams["figure.figsize"] = (10,4)
time1 = np.arange(0,314)

d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
P = f1(time1)
#M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
#E=106
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/4000

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100

#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='--', color = 'black',label='VT_20')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20752\890982436.py:40: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='--', color = 'black',label='VT_20')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['Time', 'Extension', 'Load']  
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\Arbitrary_sample\Arbitrary_sample_3\arbitrarysample_3\\A7_VT40_D_1(15N, 0.51).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

#plt.rcParams["figure.figsize"] = (10,4)
time1 = np.arange(0,314)

d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
P = f1(time1)
#M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
#E=106
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/4000

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100

#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='--', color = 'black',label='VT30')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20752\2692913198.py:40: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='--', color = 'black',label='VT30')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['Time', 'Extension', 'Load']  
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\Arbitrary_sample\Arbitrary_sample_3\arbitrarysample_3\\A7_VT40_D_1(15N, 0.51).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

#plt.rcParams["figure.figsize"] = (10,4)
time1 = np.arange(0,314)

d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
P = f1(time1)
#M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
#E=106
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/4000

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100

#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='--', color = 'black',label='VT_40')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20752\3624708040.py:40: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='--', color = 'black',label='VT_40')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['Time', 'Extension', 'Load']  
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\Arbitrary_sample\Arbitrary_sample_3\arbitrarysample_3\\A7_VT20_D_9(2.67 N, 0.83).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

#plt.rcParams["figure.figsize"] = (10,4)
time1 = np.arange(0,314)

d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
P = f1(time1)
#M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
#E=106
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40000

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100

#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='-', color = 'blue',label='A7_VT10_Sealed')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
#plt.show()

#######################################################################################

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,100)
headers = ['Time', 'Extension', 'Load']  
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\Arbitrary_sample\Arbitrary_sample_3\arbitrarysample_3\\A7_VT40_D_5(6.45 N, 0.73).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

#plt.rcParams["figure.figsize"] = (10,4)
time1 = np.arange(0,214)

d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
P = f1(time1)
#M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
#E=106
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/4000

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*60

#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='-', color = 'orange',label='A7_VT20_Sealed')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
# plt.show()



###########################################################################################


# import matplotlib.pyplot as plt
# import pandas as pd
# import numpy as np

# r2 = 7.132
# e = .05
# v = .2
# eprime = e
# t = 2.14

# skip = np.arange(0,1)
# headers = ['Time', 'Extension', 'Load']  
# df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\Arbitrary_sample\Arbitrary_sample_3\arbitrarysample_3\\A7_VT20_D_10(2.3 N, 0.94).csv',names = headers, skiprows=skip)


# from scipy.interpolate import interp1d

# #plt.rcParams["figure.figsize"] = (10,4)
# time1 = np.arange(0,314)

# d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
# d = d1(time1)

# f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
# P = f1(time1)
# #M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
# M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
# E = 1.4177*(10**-6)*(320**3.25)/1000
# #E=106
# D = (E*(t**3))/(12*(1-(v**2)))

# # stress = 6*M/(t**2)
# stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/4000

# dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

# strain_per = d/dmax*100

# #plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
# plt.plot(strain_per, stress, '-', linestyle='-', color = 'green',label='VT_20')
# plt.legend(loc='best')
# plt.title('Aging Strengths', fontdict={'fontsize': 10})
# plt.xlabel('% Strain',fontdict={'fontsize': 10})
# plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
# #plt.show()

#################################################################################

# import matplotlib.pyplot as plt
# import pandas as pd
# import numpy as np

# r2 = 7.132
# e = .05
# v = .2
# eprime = e
# t = 2.14

# skip = np.arange(0,1)
# headers = ['Time', 'Extension', 'Load']  
# df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\Arbitrary_sample\Arbitrary_sample_3\arbitrarysample_3\\A7_VT40_D_1(15N, 0.51).csv',names = headers, skiprows=skip)


# from scipy.interpolate import interp1d

# #plt.rcParams["figure.figsize"] = (10,4)
# time1 = np.arange(0,314)

# d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
# d = d1(time1)

# f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
# P = f1(time1)
# #M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
# M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
# E = 1.4177*(10**-6)*(320**3.25)/1000
# #E=106
# D = (E*(t**3))/(12*(1-(v**2)))

# # stress = 6*M/(t**2)
# stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/4000

# dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

# strain_per = d/dmax*100

# #plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
# plt.plot(strain_per, stress, '-', linestyle='-', color = 'orange',label='VT_30')
# plt.legend(loc='best')
# plt.title('Aging Strengths', fontdict={'fontsize': 10})
# plt.xlabel('% Strain',fontdict={'fontsize': 10})
# plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
# #plt.show()

############################################################################################

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['Time', 'Extension', 'Load']  
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\Arbitrary_sample\Arbitrary_sample_3\arbitrarysample_3\\A7_VT40_D_1(15N, 0.51).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

#plt.rcParams["figure.figsize"] = (10,4)
time1 = np.arange(0,314)

d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
P = f1(time1)
#M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
#E=106
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/4000

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100

#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='-', color = 'purple',label='A7_VT30_Sealed')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
#plt.show()

#######################################################################################

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['Time', 'Extension', 'Load']  
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\Arbitrary_sample\Arbitrary_sample_3\arbitrarysample_3\\A7_VT40_d_2(3.5N, 0.9).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

#plt.rcParams["figure.figsize"] = (10,4)
time1 = np.arange(0,314)

d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
P = f1(time1)
#M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
#E=106
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/4000

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100

#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='-', color = 'green',label='A7_VT40_Sealed')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.show()

######################################################################################

# import matplotlib.pyplot as plt
# import pandas as pd
# import numpy as np

# r2 = 7.132
# e = .05
# v = .2
# eprime = e
# t = 2.14

# skip = np.arange(0,1)
# headers = ['Time', 'Extension', 'Load']  
# df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\Arbitrary_sample\Arbitrary_sample_3\arbitrarysample_3\\A7_VT40_D_4(4N, 0.45).csv',names = headers, skiprows=skip)


# from scipy.interpolate import interp1d

# #plt.rcParams["figure.figsize"] = (10,4)
# time1 = np.arange(0,314)

# d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
# d = d1(time1)

# f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
# P = f1(time1)
# #M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
# M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
# E = 1.4177*(10**-6)*(320**3.25)/1000
# #E=106
# D = (E*(t**3))/(12*(1-(v**2)))

# # stress = 6*M/(t**2)
# stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/400

# dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*100

# strain_per = d/dmax*100

# #plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
# plt.plot(strain_per, stress, '-', linestyle='--', color = 'green',label='VT_30')
# plt.legend(loc='best')
# plt.title('Aging Strengths', fontdict={'fontsize': 10})
# plt.xlabel('% Strain',fontdict={'fontsize': 10})
# plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
# #plt.show()

# ##########################################################################################

# import matplotlib.pyplot as plt
# import pandas as pd
# import numpy as np

# r2 = 7.132
# e = .05
# v = .2
# eprime = e
# t = 2.14

# skip = np.arange(0,1)
# headers = ['Time', 'Extension', 'Load']  
# df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\Arbitrary_sample\Arbitrary_sample_3\arbitrarysample_3\\A7_VT40_D_5(6.45 N, 0.73).csv',names = headers, skiprows=skip)


# from scipy.interpolate import interp1d

# #plt.rcParams["figure.figsize"] = (10,4)
# time1 = np.arange(0,314)

# d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
# d = d1(time1)

# f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
# P = f1(time1)
# #M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
# M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
# E = 1.4177*(10**-6)*(320**3.25)/1000
# #E=106
# D = (E*(t**3))/(12*(1-(v**2)))

# # stress = 6*M/(t**2)
# stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/4000

# dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

# strain_per = d/dmax*1000

# #plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
# plt.plot(strain_per, stress, '-', linestyle='--', color = 'orange',label='VT_20')
# plt.legend(loc='best')
# plt.title('Aging Strengths', fontdict={'fontsize': 10})
# plt.xlabel('% Strain',fontdict={'fontsize': 10})
# plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
#plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20752\684178178.py:40: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='-', color = 'blue',label='A7_VT10_Sealed')
# C:\Users\user\AppData\Local\Temp\ipykernel_20752\684178178.py:88: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='-', color = 'orange',label='A7_VT20_Sealed')
# C:\Users\user\AppData\Local\Temp\ipykernel_20752\684178178.py:235: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='-', color = 'purple',label='A7_VT30_Sealed')
# C:\Users\user\AppData\Local\Temp\ipykernel_20752\684178178.py:283: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='-', color = 'green',label='A7_VT40_Sealed')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['Time', 'Extension', 'Load']  
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\Arbitrary_sample\Arbitrary_sample_3\arbitrarysample_3\\A7_VT40_D_5(6.45 N, 0.73).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

#plt.rcParams["figure.figsize"] = (10,4)
time1 = np.arange(0,314)

d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
P = f1(time1)
#M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
#E=106
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/4000

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100

#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='--', color = 'orange',label='VT_20')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20752\665693173.py:40: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='--', color = 'orange',label='VT_20')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['Time', 'Extension', 'Load']  
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\Arbitrary_sample\Arbitrary_sample_3\arbitrarysample_3\\A7_VT40_D_4(4N, 0.45).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

#plt.rcParams["figure.figsize"] = (10,4)
time1 = np.arange(0,314)

d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
P = f1(time1)
#M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
#E=106
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/400

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*0

#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='--', color = 'green',label='VT_30')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20752\2497244942.py:40: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='--', color = 'green',label='VT_30')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['Time', 'Extension', 'Load']  
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\Arbitrary_sample\Arbitrary_sample_3\arbitrarysample_3\\A7_withouSeal_7(0.42N,0.29).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

#plt.rcParams["figure.figsize"] = (10,4)
time1 = np.arange(0,314)

d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
P = f1(time1)
#M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
#E=106
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100

#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='--', color = 'red',label='A1_Without')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20752\1706360696.py:40: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='--', color = 'red',label='A1_Without')
