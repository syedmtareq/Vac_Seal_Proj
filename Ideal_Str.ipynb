# %%
## Strength test_Ideal Sample

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

#C:\Users\user\Desktop\Vac_Seal\IdealSample\idealsample_strength
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\IdealSample\idealsample_strength\\Specimen_RawData_1.csv')
df
# Out:
#          Time     Load  Extension
# 0       0.000  0.00000   -0.05478
# 1       0.026  0.00000   -0.07892
# 2       0.060  0.00000   -0.04224
# 3       0.086  0.00011   -0.03942
# 4       0.112  0.00017   -0.05321
# ...       ...      ...        ...
# 4612  119.920  0.99932    3.11432
# 4613  119.946  0.99954    3.07545
# 4614  119.972  0.99977    3.10743
# 4615  119.998  1.00000    3.09112
# 4616  120.004  1.00005    3.08047
#
# [4617 rows x 3 columns]

# %%
from scipy.signal import lfilter

plt.rcParams["figure.figsize"] = (16,10)

# plt.plot(df.Extension, df['16 D_without seal'])
n = 100  # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
yy = lfilter(b,a, df['Specimen_RawData_1'])
#plt.plot(df.Extension, yy, linewidth=2, linestyle="-", color="blue")7 D_1_with
plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='Specimen_RawData_1')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Specimen_RawData_1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [110], in <cell line: 9>()
#       7 b = [1.0 / n] * n
#       8 a = 1
# ----> 9 yy = lfilter(b,a, df['Specimen_RawData_1'])
#      10 #plt.plot(df.Extension, yy, linewidth=2, linestyle="-", color="blue")7 D_1_with
#      11 plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='Specimen_RawData_1')
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Specimen_RawData_1'

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

#C:\Users\user\Desktop\Vac_Seal\IdealSample\idealsample_strength
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\IdealSample\idealsample_strength\\Specimen_RawData_1_1.csv')
df
# Out:
#          Time  Extension  A1_Sealed  A1_Without  A3_Sealed  A3_Without  \
# 0       0.000    0.00000   -0.05478    -0.03472    0.20667    -0.02406
# 1       0.026    0.00000   -0.07892     0.00133    0.16999     0.00384
# 2       0.060    0.00000   -0.04224    -0.08205    0.18285    -0.03503
# 3       0.086    0.00011   -0.03942    -0.13033    0.24367    -0.08017
# 4       0.112    0.00017   -0.05321    -0.07798    0.21043    -0.01497
# ...       ...        ...        ...         ...        ...         ...
# 4612  119.920    0.99932    3.11432         NaN    7.77785    -0.08331
# 4613  119.946    0.99954    3.07545         NaN    7.72362    -0.07046
# 4614  119.972    0.99977    3.10743         NaN    7.73459    -0.08989
# 4615  119.998    1.00000    3.09112         NaN    7.74493    -0.09052
# 4616  120.004    1.00005    3.08047         NaN    7.74681    -0.09554
#
#       A7_Sealed  A7_Without  A14_Sealed  A14_Without  A21_Sealed  A21_Without  \
# 0      -0.02092    -0.08738     0.19946     -0.02061     2.44282     -0.02437
# 1      -0.05948    -0.07516     0.24492      0.00384     2.41868     -0.05635
# 2      -0.05792    -0.01152     0.19915     -0.02625     2.35912      0.02422
# 3      -0.02845    -0.03973     0.27219      0.07783     2.45818      0.07281
# 4      -0.06889    -0.05227     0.30511      0.03394     2.47731      0.08755
# ...         ...         ...         ...          ...         ...          ...
# 4612        NaN         NaN     2.96698          NaN         NaN          NaN
# 4613        NaN         NaN     2.96134          NaN         NaN          NaN
# 4614        NaN         NaN     2.93720          NaN         NaN          NaN
# 4615        NaN         NaN     2.96197          NaN         NaN          NaN
# 4616        NaN         NaN         NaN          NaN         NaN          NaN
#
#       A39_Sealed  A39_Without
# 0       -0.13378     -0.13754
# 1       -0.07140     -0.27015
# 2       -0.15353     -0.36545
# 3       -0.14287     -0.29868
# 4       -0.11403     -0.22658
# ...          ...          ...
# 4612     6.59410          NaN
# 4613     6.60350          NaN
# 4614     6.56808          NaN
# 4615     6.56714          NaN
# 4616     6.55742          NaN
#
# [4617 rows x 14 columns]

# %%
from scipy.signal import lfilter

plt.rcParams["figure.figsize"] = (16,10)

# plt.plot(df.Extension, df['16 D_without seal'])
n = 1  # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
yy = lfilter(b,a, df['Without'])
#plt.plot(df.Extension, yy, linewidth=2, linestyle="-", color="blue")7 D_1_with
plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="yellow", label='Without')



# plt.plot(df.Extension, df['16 D_with seal'])
n = 100  # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
yy = lfilter(b,a, df1['VT10_S'])
#plt.plot(df.Extension, yy, linewidth=2, linestyle="-", color="red")
plt.plot(df.Extension, yy, linewidth=2, linestyle="dashed", color="blue", label='VT10_S' )


# plt.plot(df.Extension, df['21 D_without seal'])
n = 1  # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
yy = lfilter(b,a, df1['VT10_D'])
plt.plot(df1.Extension, yy, linewidth=2, linestyle='-', color="blue",label='VT10_D' )





# plt.plot(df.Extension, df['21 D_with seal'])
n = 10  # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
yy = lfilter(b,a, df1['VT20_S'])
plt.plot(df1.Extension, yy, linewidth=2, linestyle="dashed", color="green", label='VT20_S' )


# plt.plot(df.Extension, df['21 D_with seal'])
n = 5  # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
yy = lfilter(b,a, df1['VT20_D'])
plt.plot(df1.Extension, yy, linewidth=2, linestyle="-", color="green", label='VT20_D' )


# plt.plot(df.Extension, df['21 D_with seal'])
n = 2  # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
yy = lfilter(b,a, df1['VT40_S'])
plt.plot(df1.Extension, yy, linewidth=2, linestyle="dashed", color="orange", label='VT40_S' )


# plt.plot(df.Extension, df['21 D_with seal'])
n = 100  # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
yy = lfilter(b,a, df1['VT40_D'])
plt.plot(df1.Extension, yy, linewidth=2, linestyle="-", color="orange", label='VT40_D' )

plt.legend(loc='best',fontsize=14)
plt.title('Load vs Extension', fontdict={'fontsize': 16})
plt.xlabel('Extension (mm)',fontdict={'fontsize': 14})
plt.ylabel('Load(N)',fontdict={'fontsize': 14})

# plt.ylim(0,1000)
plt.xlim(0.001,0.4)

# plt.legend()

# plt.plot(strain_per, stress, '-', color = 'g',linestyle='dashed', label='21 Days_without sealing')
# plt.legend(loc='best',fontsize=14)
# plt.title('Aging Strengths', fontdict={'fontsize': 16})
# plt.xlabel('% Strain',fontdict={'fontsize': 14})
# plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 14})

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Without'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [107], in <cell line: 9>()
#       7 b = [1.0 / n] * n
#       8 a = 1
# ----> 9 yy = lfilter(b,a, df['Without'])
#      10 #plt.plot(df.Extension, yy, linewidth=2, linestyle="-", color="blue")7 D_1_with
#      11 plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="yellow", label='Without')
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Without'

# %%
####  Flexural stress

# %%
# A1 With

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,2)
headers = ['Time', 'Load', 'Extension']  
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\IdealSample\idealsample_strength\\Specimen_RawData_1.csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d
plt.rcParams["figure.figsize"] = (10,4)
time1 = np.arange(0,120)
d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
# M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
#E = 1.4177*(10**-6)*(320**3.25)/1000
E=106
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='-', color = 'yellow',label='A1_Sealed')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})



plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8448\3981415907.py:37: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='-', color = 'yellow',label='A1_Sealed')

# %%
# A1 Without

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,2)
headers = ['Time', 'Load', 'Extension']  
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\IdealSample\idealsample_strength\\Specimen_RawData_4.csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d
plt.rcParams["figure.figsize"] = (10,4)
time1 = np.arange(0,320)
d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
# M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
#E = 1.4177*(10**-6)*(320**3.25)/1000
E=106
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='--', color = 'yellow',label='A1_Without')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8448\91434444.py:37: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='--', color = 'yellow',label='A1_Without')

# %%
# A3 Sealed

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['Time', 'Load', 'Extension']  
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\IdealSample\idealsample_strength\\Specimen_RawData_5.csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d
plt.rcParams["figure.figsize"] = (10,4)
time1 = np.arange(0,120)
d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
# M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
#E = 1.4177*(10**-6)*(320**3.25)/1000
E=106
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='-', color = 'orange',label='A3_Sealed')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8448\1473182639.py:37: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='-', color = 'orange',label='A3_Sealed')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['Time', 'Load', 'Extension']  
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\IdealSample\idealsample_strength\\Specimen_RawData_6.csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d
plt.rcParams["figure.figsize"] = (10,4)
time1 = np.arange(0,320)
d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
# M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
#E = 1.4177*(10**-6)*(320**3.25)/1000
E=106
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='--', color = 'orange',label='A3_Without')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})




plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8448\3026772545.py:37: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='--', color = 'orange',label='A3_Without')

# %%
## A7 Sealed

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['Time', 'Load', 'Extension']  
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\IdealSample\idealsample_strength\\Specimen_RawData_8.csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d
plt.rcParams["figure.figsize"] = (10,4)
time1 = np.arange(0,60)
d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
# M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
#E = 1.4177*(10**-6)*(320**3.25)/1000
E=106
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='-', color = 'blue',label='A7_Sealed')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8448\2441023701.py:37: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='-', color = 'blue',label='A7_Sealed')

# %%
# # A7 Without

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['Time', 'Load', 'Extension']  
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\IdealSample\idealsample_strength\\Specimen_RawData_10.csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d
plt.rcParams["figure.figsize"] = (10,4)
time1 = np.arange(0,120)
d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
# M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
#E = 1.4177*(10**-6)*(320**3.25)/1000
E=106
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='--', color = 'blue',label='A7_Without')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8448\2915743012.py:37: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='--', color = 'blue',label='A7_Without')

# %%
## A14 Sealed

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['Time', 'Load', 'Extension']  
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\IdealSample\idealsample_strength\\Specimen_RawData_11.csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d
plt.rcParams["figure.figsize"] = (10,4)
time1 = np.arange(0,120)
d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
# M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
#E = 1.4177*(10**-6)*(320**3.25)/1000
E=106
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='-', color = 'green',label='A14_Sealed')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8448\1600240278.py:37: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='-', color = 'green',label='A14_Sealed')

# %%
# A 14 Without

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['Time', 'Load', 'Extension']  
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\IdealSample\idealsample_strength\\Specimen_RawData_14.csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d
plt.rcParams["figure.figsize"] = (10,4)
time1 = np.arange(0,320)
d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
# M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
#E = 1.4177*(10**-6)*(320**3.25)/1000
E=106
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='--', color = 'green',label='A14_Without')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8448\2067999637.py:37: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='--', color = 'green',label='A14_Without')

# %%
# A21 Sealed

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['Time', 'Load', 'Extension']  
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\IdealSample\idealsample_strength\\Specimen_RawData_15.csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d
plt.rcParams["figure.figsize"] = (10,4)
time1 = np.arange(0,90)
d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
# M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
#E = 1.4177*(10**-6)*(320**3.25)/1000
E=106
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='-', color = 'purple',label='A21_Sealed')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8448\1792951098.py:37: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='-', color = 'purple',label='A21_Sealed')

# %%
# A21 Without

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['Time', 'Load', 'Extension']  
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\IdealSample\idealsample_strength\\Specimen_RawData_17.csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d
plt.rcParams["figure.figsize"] = (10,4)
time1 = np.arange(0,90)
d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
# M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
#E = 1.4177*(10**-6)*(320**3.25)/1000
E=106
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='--', color = 'purple',label='A21_Without')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8448\1044030408.py:37: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='--', color = 'purple',label='A21_Without')

# %%
## A39 Sealed

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['Time', 'Load', 'Extension']  
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\IdealSample\idealsample_strength\\Specimen_RawData_18.csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d
plt.rcParams["figure.figsize"] = (10,4)
time1 = np.arange(0,90)
d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
# M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
#E = 1.4177*(10**-6)*(320**3.25)/1000
E=106
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='-', color = 'black',label='A39_Sealed')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8448\2599740060.py:37: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='-', color = 'black',label='A39_Sealed')

# %%
## A39 Without

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['Time', 'Load', 'Extension']  
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\IdealSample\idealsample_strength\\Specimen_RawData_20.csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d
plt.rcParams["figure.figsize"] = (10,4)
time1 = np.arange(0,50)
d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
# M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
#E = 1.4177*(10**-6)*(320**3.25)/1000
E=106
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='--', color = 'black',label='A39_Without')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8448\1034574213.py:37: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='--', color = 'black',label='A39_Without')

# %%
####Combining the plot

# %%
##########  A1 With 

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,2)
headers = ['Time', 'Load', 'Extension']  
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\IdealSample\idealsample_strength\\Specimen_RawData_1.csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d
plt.rcParams["figure.figsize"] = (10,4)
time1 = np.arange(0,120)
d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
# M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
#E = 1.4177*(10**-6)*(320**3.25)/1000
E=106
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='-', color = 'yellow',label='A1_Sealed')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})

####################################################################################  A1 without
 
    
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,2)
headers = ['Time', 'Load', 'Extension']  
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\IdealSample\idealsample_strength\\Specimen_RawData_4.csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d
plt.rcParams["figure.figsize"] = (10,4)
time1 = np.arange(0,320)
d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
# M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
#E = 1.4177*(10**-6)*(320**3.25)/1000
E=106
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='--', color = 'yellow',label='A1_Without')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})


###################################################################################################### A3 With

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['Time', 'Load', 'Extension']  
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\IdealSample\idealsample_strength\\Specimen_RawData_5.csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d
plt.rcParams["figure.figsize"] = (10,4)
time1 = np.arange(0,120)
d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
# M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
#E = 1.4177*(10**-6)*(320**3.25)/1000
E=106
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='-', color = 'orange',label='A3_Sealed')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})


#################################################################################### A3 Without


import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['Time', 'Load', 'Extension']  
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\IdealSample\idealsample_strength\\Specimen_RawData_6.csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d
plt.rcParams["figure.figsize"] = (10,4)
time1 = np.arange(0,320)
d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
# M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
#E = 1.4177*(10**-6)*(320**3.25)/1000
E=106
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='--', color = 'orange',label='A3_Without')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})


############################################################################## A7 With 

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['Time', 'Load', 'Extension']  
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\IdealSample\idealsample_strength\\Specimen_RawData_8.csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d
plt.rcParams["figure.figsize"] = (10,4)
time1 = np.arange(0,60)
d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
# M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
#E = 1.4177*(10**-6)*(320**3.25)/1000
E=106
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='-', color = 'blue',label='A7_Sealed')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})

############################################################################## A7 Without 

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['Time', 'Load', 'Extension']  
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\IdealSample\idealsample_strength\\Specimen_RawData_10.csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d
plt.rcParams["figure.figsize"] = (10,4)
time1 = np.arange(0,120)
d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
# M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
#E = 1.4177*(10**-6)*(320**3.25)/1000
E=106
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='--', color = 'blue',label='A7_Without')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})

################################################################################ A14 With 

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['Time', 'Load', 'Extension']  
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\IdealSample\idealsample_strength\\Specimen_RawData_11.csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d
plt.rcParams["figure.figsize"] = (10,4)
time1 = np.arange(0,120)
d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
# M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
#E = 1.4177*(10**-6)*(320**3.25)/1000
E=106
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='-', color = 'green',label='A14_Sealed')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})


###################################################################################### A14 Without


import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['Time', 'Load', 'Extension']  
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\IdealSample\idealsample_strength\\Specimen_RawData_14.csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d
plt.rcParams["figure.figsize"] = (10,4)
time1 = np.arange(0,320)
d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
# M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
#E = 1.4177*(10**-6)*(320**3.25)/1000
E=106
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='--', color = 'green',label='A14_Without')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})



######################################################################### A21 With 


import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['Time', 'Load', 'Extension']  
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\IdealSample\idealsample_strength\\Specimen_RawData_15.csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d
plt.rcParams["figure.figsize"] = (10,4)
time1 = np.arange(0,90)
d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
# M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
#E = 1.4177*(10**-6)*(320**3.25)/1000
E=106
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='-', color = 'purple',label='A21_Sealed')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})


############################################################################ A21 Without 

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['Time', 'Load', 'Extension']  
df = pd.read_csv(r'C:\Users\user\Desktop\Vac_Seal\IdealSample\idealsample_strength\\Specimen_RawData_17.csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d
plt.rcParams["figure.figsize"] = (10,4)
time1 = np.arange(0,90)
d1 = interp1d(df['Time'],df['Extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['Time'],df['Load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/(4*np.pi))*((1+v)*np.log(r2/(2*eprime))+1)
# M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
#E = 1.4177*(10**-6)*(320**3.25)/1000
E=106
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='--', color = 'purple',label='A21_Without')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})


plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8448\1646308193.py:39: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='-', color = 'yellow',label='A1_Sealed')
# C:\Users\user\AppData\Local\Temp\ipykernel_8448\1646308193.py:84: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='--', color = 'yellow',label='A1_Without')
# C:\Users\user\AppData\Local\Temp\ipykernel_8448\1646308193.py:129: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='-', color = 'orange',label='A3_Sealed')
# C:\Users\user\AppData\Local\Temp\ipykernel_8448\1646308193.py:175: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='--', color = 'orange',label='A3_Without')
# C:\Users\user\AppData\Local\Temp\ipykernel_8448\1646308193.py:220: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='-', color = 'blue',label='A7_Sealed')
# C:\Users\user\AppData\Local\Temp\ipykernel_8448\1646308193.py:264: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='--', color = 'blue',label='A7_Without')
# C:\Users\user\AppData\Local\Temp\ipykernel_8448\1646308193.py:308: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='-', color = 'green',label='A14_Sealed')
# C:\Users\user\AppData\Local\Temp\ipykernel_8448\1646308193.py:354: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='--', color = 'green',label='A14_Without')
# C:\Users\user\AppData\Local\Temp\ipykernel_8448\1646308193.py:401: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='-', color = 'purple',label='A21_Sealed')
# C:\Users\user\AppData\Local\Temp\ipykernel_8448\1646308193.py:446: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(strain_per, stress, '-', linestyle='--', color = 'purple',label='A21_Without')

# %%
##### Combining the plot 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
plt.rcParams["figure.figsize"] = (16,6)

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_3\\A7_withouSeal_7(0.42N,0.29).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

time1 = np.arange(0,314)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='-', color = 'yellow',label='A7_without')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
#plt.show()
########################################################################################
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_3\\A7_VT10_S_11(1.35 N, 0.194).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

time1 = np.arange(0,314)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='dashed', color = 'blue',label='A7_VT10_S')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
#plt.show()
######################################################################################

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_3\\A7_VT10_D_10(2.3 N, 0.94).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

time1 = np.arange(0,314)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle="dashed", color="orange", label='7 D_2_without' )
plt.plot(strain_per, stress, '-', linestyle='-', color = 'blue',label='A7_VT10_D')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
#plt.show()
#################################################################################

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_3\\A7_VT20_S_9(2.67 N, 0.83).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

time1 = np.arange(0,314)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='dashed', color = 'g',label='A7_VT20_S')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
# plt.show()
#######################################################################################


import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_3\\A7_VT20_D_6(3.56N, .77).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

time1 = np.arange(0,100)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle="dashed", color="orange", label='7 D_2_without' )
plt.plot(strain_per, stress, '-', linestyle='-', color = 'g',label='A7_VT20_D')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
# plt.show()

###################################################################################

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_3\\A7_VT40_D_4(4N, 0.45).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

time1 = np.arange(0,314)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))

# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle='-', color="blue", label='7 D_1_with')
plt.plot(strain_per, stress, '-', linestyle='dashed', color = 'orange',label='A7_VT40_S')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
#plt.show()
#####################################################################################

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

r2 = 7.132
e = .05
v = .2
eprime = e
t = 2.14

skip = np.arange(0,1)
headers = ['time', 'extension', 'load']  
df = pd.read_csv('D:\Yang\Practice\ArbitrarySample_3\\A7_Without(3.5N, 0.9).csv',names = headers, skiprows=skip)


from scipy.interpolate import interp1d

time1 = np.arange(0,314)
d1 = interp1d(df['time'],df['extension'], fill_value = 'extrapolate')
d = d1(time1)

f1 = interp1d(df['time'],df['load'], fill_value = 'extrapolate')
P = f1(time1)
M = (P/4/np.pi)*((1+v)*np.log(r2/2/eprime)+1)
E = 1.4177*(10**-6)*(320**3.25)/1000
D = (E*(t**3))/(12*(1-(v**2)))


# stress = 6*M/(t**2)
stress = np.convolve(6*M/(t**2),np.ones(40),mode = 'same')/40

dmax = ((3+v)*P.max()*((r2/2**2)))/(16*np.pi*(1+v)*D)*1000

strain_per = d/dmax*100
#plt.plot(df.Extension, yy, linewidth=2, linestyle="dashed", color="orange", label='7 D_2_without' )
plt.plot(strain_per, stress, '-', linestyle='-', color = 'orange',label='A7_VT40_D')
plt.legend(loc='best')
plt.title('Aging Strengths', fontdict={'fontsize': 10})
plt.xlabel('% Strain',fontdict={'fontsize': 10})
plt.ylabel('Flexural Stress (MPa)',fontdict={'fontsize': 10})
plt.ylim(0,1000)
plt.xlim(0,.005)
plt.show()
